# %% [markdown]
# # 1주차. pandas로 시작하는 빅데이터 분석
#
#
# - 1주차에는 코드랑 인사하는 시간
# - 데이터를 다루는 기본 흐름을 느껴보세요

# %% [markdown]
# ## 학습 목표 (1주차 끝나면 할 수 있어야 합니다)
# 1. read_csv() 함수를 이용하여 데이터를 불러오고 info() 함수를 통해 구조와 자료형을 확인할 수 있다
# 2. 열 선택(Series vs DataFrame)을 할 수 있다 (`df['col']` vs `df[['col_1','col_2']]`)
# 3. 조건을 사용해 필요한 행만 골라낼 수 있다 (Boolean filtering)
# 4. sort_values() 함수를 사용하여 오름차순 또는 내림차순으로 정렬할 수 있고 `mean()`, `max()`, `min()` 같은 함수(메서드)를 사용할 수 있다
# 5. pandas의 `plot()` 함수로 빠르게 그래프를 그려 볼 수 있다
# 6. 데이터를 처음 보았을때 범주형 데이터의 경우 unique(), value_counts() 함수를 사용해 어떤 값들이 있는 지 빠르게 파악할 수 있다

# %% [markdown]
# ## 첫 수업에서 사용할 데이터
# - 파일: data1.csv
# - 내용: 월별(1~12월) 기상 데이터
# - 주요 열
#   - `month`: 월(1~12)
#   - `avgTa`: 평균기온(℃)
#   - `minTa`: 최저기온(℃)
#   - `maxTa`: 최고기온(℃)
#   - `sumRn`: 강수량(mm)
#   - `avgRhm`: 평균상대습도(%)
#   - `avgWs`: 평균풍속(m/s)

# %% [markdown]
# ## 위의 코드를 아래 비어있는 셀에 코딩하고 실행후 결과를 확인합니다!!

# %% [markdown]
# ## 1. pandas 라이브러리를 불러와서 pd로 선언 후 read_csv() 함수로 데이터 파일 읽기

# %% [markdown]
# - pandas라는 데이터 분석 라이브러를 가져와서,앞으로는 pd라는 짧은 이름으로 사용할 것임
# - csv 파일 : comma-separated values, 값들을 쉼표 , 로 구분해서 저장한 파일

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv('data1.csv')
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %%
df = pd.read_csv('data1.csv')

# %%
df
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %%
df
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %% [markdown]
# ## 2. 데이터 구조 확인

# %% [markdown]
# - info() 함수를 사용하여 구조와 자료형 확인

# %%
df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   12 non-null     int64
#  1   avgTa   12 non-null     float64
#  2   minTa   12 non-null     float64
#  3   maxTa   12 non-null     float64
#  4   sumRn   12 non-null     float64
#  5   avgRhm  12 non-null     float64
#  6   avgWs   12 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 804.0 bytes

# %% [markdown]
# - head() 함수를 사용하여 데이터 앞부분 보기

# %%
df.head()

# %%
df.head()
# Out:
#    month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0      1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1      2   1.58  -2.40   6.28   2.42   55.36   2.84
# 2      3   9.44   5.00  14.68   3.34   57.10   2.92
# 3      4  14.36   9.30  20.00   6.04   59.16   2.66
# 4      5  17.88  13.62  22.64   8.44   67.48   2.34

# %%
df.head(3)

# %%
df.head(3)
# Out:
#    month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0      1   2.54   -1.2   7.06   1.16   58.42   2.54
# 1      2   1.58   -2.4   6.28   2.42   55.36   2.84
# 2      3   9.44    5.0  14.68   3.34   57.10   2.92

# %% [markdown]
# - tail() 함수를 사용하여 데이터 뒷부분 보기

# %%
df.tail()

# %%
df.tail()
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %%
df.tail(2)

# %%
df.tail(2)
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %% [markdown]
# - columns 속성을 사용하여 열들의 목록 보기

# %%
df.columns

# %%
df.columns
# Out:
# Index(['month', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgRhm', 'avgWs'], dtype='object')

# %% [markdown]
# ---
# ## 오늘 가장 중요한 개념: **Series vs DataFrame**
#
# pandas는 두 가지 기본 자료구조를 사용합니다.
#
# - **DataFrame**: 표(2차원) — 행과 열이 있는 데이터 **테이블**
# - **Series**: 열 하나(1차원) — DataFrame에서 열을 하나 뽑아낸 것

# %% [markdown]
# ## 3. 열 선택

# %% [markdown]
# ### 3-1) 하나의 열 선택
#
#
# df['col']
#
# - 결과 타입: `Series`
# - “열 하나”를 **값들의 리스트처럼** 다룬다

# %%
df

# %%
df
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %%
df.columns

# %%
df.columns
# Out:
# Index(['month', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgRhm', 'avgWs'], dtype='object')

# %%
df['avgTa']

# %%
df['avgTa']
# Out:
# 0      2.54
# 1      1.58
# 2      9.44
# 3     14.36
# 4     17.88
# 5     23.54
# 6     28.28
# 7     28.42
# 8     24.70
# 9     18.66
# 10    11.16
# 11     4.94
# Name: avgTa, dtype: float64

# %%
type(df['avgTa'])

# %%
type(df['avgTa'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# - 결과 타입: Series
# - 평균기온 값만 1차원으로 확인

# %% [markdown]
# ### 2-2) 여러 열 선택
#
# 여러 열을 선택할 때는 **반드시 리스트**를 사용합니다.
#
# df[['col_1', 'col_2']]

# %%
df[ ['minTa', 'maxTa'] ]

# %%
df[ ['minTa', 'maxTa'] ]
# Out:
#     minTa  maxTa
# 0   -1.20   7.06
# 1   -2.40   6.28
# 2    5.00  14.68
# 3    9.30  20.00
# 4   13.62  22.64
# 5   19.72  27.92
# 6   24.96  32.26
# 7   25.34  32.36
# 8   21.82  28.66
# 9   15.64  22.64
# 10   6.84  16.38
# 11   0.72   9.58

# %%
df[[ 'month', 'minTa', 'maxTa']]

# %%
df[[ 'month', 'minTa', 'maxTa']]
# Out:
#     month  minTa  maxTa
# 0       1  -1.20   7.06
# 1       2  -2.40   6.28
# 2       3   5.00  14.68
# 3       4   9.30  20.00
# 4       5  13.62  22.64
# 5       6  19.72  27.92
# 6       7  24.96  32.26
# 7       8  25.34  32.36
# 8       9  21.82  28.66
# 9      10  15.64  22.64
# 10     11   6.84  16.38
# 11     12   0.72   9.58

# %% [markdown]
# #### 왜 대괄호가 두 개인가?
# - 바깥 `[]` : DataFrame에서 선택
# - 안쪽 `[]` : 선택할 열 이름들의 목록(list)

# %%
df[['month', 'avgTa']]

# %%
df[['month', 'avgTa']]
# Out:
#     month  avgTa
# 0       1   2.54
# 1       2   1.58
# 2       3   9.44
# 3       4  14.36
# 4       5  17.88
# 5       6  23.54
# 6       7  28.28
# 7       8  28.42
# 8       9  24.70
# 9      10  18.66
# 10     11  11.16
# 11     12   4.94

# %% [markdown]
# 자주 하는 실수(에러):
# `df['month', 'avgTa']`

# %% [markdown]
# ## 4. 조건 필터링 (행 선택) - 데이터 분석의 핵심 기술
# -조건 필터링은 필요한 데이터만 골라서 보는 것
#
# - df[조건]
#
# - 비교연산자 : >, >=, <, <=, ==, !=
#
# - 예: 평균기온이 20도 이상인 데이터를 선택,  df[df['avgTa'] >= 20]

# %%
df['avgTa']  > 20     # 조건

# %%
df['avgTa']  > 20
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# Name: avgTa, dtype: bool

# %%
df[ df['avgTa']  > 20   ]

# %%
df[ df['avgTa']  > 20   ]
# Out:
#    month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 5      6  23.54  19.72  27.92  15.24   70.88   2.32
# 6      7  28.28  24.96  32.26  32.70   72.22   2.42
# 7      8  28.42  25.34  32.36  15.58   75.82   2.24
# 8      9  24.70  21.82  28.66  13.34   77.00   2.14

# %% [markdown]
# ### 4-1 하나의 조건

# %% [markdown]
# 문: 최저기온이 0도 이상

# %% [markdown]
# 먼저 조건을 만들기

# %%
df['minTa'] >= 0

# %%
df['minTa'] >= 0
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: minTa, dtype: bool

# %%
df[df['minTa'] >= 0]

# %%
df[df['minTa'] >= 0]
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %% [markdown]
# - 먼저 조건을 만들고 `df['minTa'] >= 0`
# - True인 행만 남김

# %% [markdown]
# ### 4-2. 두 개 이상의 조건

# %% [markdown]
# - &  : and 연산자
# - |  : or 연산자
# - 주의: 각각의 조건을 괄호 (   ) 로 묶어줄것

# %% [markdown]
# 항상 조건을 먼저 만들어 봅니다

# %% [markdown]
# 문: 최저 기온이 0 이상이고 강수량이 5 이하인 데이터를 선택

# %%
df['minTa'] >= 0

# %%
df['minTa'] >= 0
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: minTa, dtype: bool

# %%
(df['minTa'] >= 0) & (df['sumRn'] <= 5)

# %%
(df['minTa'] >= 0) & (df['sumRn'] <= 5)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool

# %%
df[ (df['minTa'] >= 0) & (df['sumRn'] <= 5) ]

# %%
df[ (df['minTa'] >= 0) & (df['sumRn'] <= 5) ]
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42

# %% [markdown]
# ## 5. 정렬 (sort_values() 함수 사용)

# %% [markdown]
# 문) df를 평균기온의 오름차순으로 정렬

# %%
df.sort_values('avgTa')

# %%
df.sort_values('avgTa')
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24

# %% [markdown]
# 문) df를 평균기온의 내림차순으로 정렬 ascending=False

# %%
df.sort_values('avgTa', ascending=False )

# %%
df.sort_values('avgTa', ascending=False )
# Out:
#     month  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 7       8  28.42  25.34  32.36  15.58   75.82   2.24
# 6       7  28.28  24.96  32.26  32.70   72.22   2.42
# 8       9  24.70  21.82  28.66  13.34   77.00   2.14
# 5       6  23.54  19.72  27.92  15.24   70.88   2.32
# 9      10  18.66  15.64  22.64   8.80   74.42   2.18
# 4       5  17.88  13.62  22.64   8.44   67.48   2.34
# 3       4  14.36   9.30  20.00   6.04   59.16   2.66
# 10     11  11.16   6.84  16.38   4.24   61.36   2.24
# 2       3   9.44   5.00  14.68   3.34   57.10   2.92
# 11     12   4.94   0.72   9.58   2.40   59.10   2.42
# 0       1   2.54  -1.20   7.06   1.16   58.42   2.54
# 1       2   1.58  -2.40   6.28   2.42   55.36   2.84

# %% [markdown]
# ## 6. 간단한 함수 사용

# %%
df['avgTa'].mean()

# %%
df['avgTa'].mean()
# Out:
# np.float64(15.458333333333334)

# %%
df['avgTa'].max()

# %%
df['avgTa'].max()
# Out:
# 28.42

# %%
df['avgTa'].min()

# %%
df['avgTa'].min()
# Out:
# 1.58

# %% [markdown]
# ## 7. pandas에서 plot() 함수를 사용하여 바로 시각화하기
#
#  **plot() 함수는 데이터(DataFrame / Series)에 이미 포함된 함수**

# %% [markdown]
# ### 7-1. Series에서 바로 시각화

# %% [markdown]
# df['avgTa'].plot()

# %%
df['avgTa'].plot()

# %%
df['avgTa'].plot()
# Out:
# <Axes: >

# %%
df['avgTa'].plot(marker='o')

# %%
df['avgTa'].plot(marker='o')
# Out:
# <Axes: >

# %% [markdown]
# 이때 x축은 Series의 index (0 ~ 11) 임을 확인하세요

# %% [markdown]
# ### 7-2. DataFrame에서 x, y 지정하여 시각화

# %%
df.plot(x='month', y='sumRn')

# %%
df.plot(x='month', y='sumRn')
# Out:
# <Axes: xlabel='month'>

# %%
df.plot(x='month' , y='avgTa' )

# %%
df.plot(x='month' , y='avgTa' )
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# month를 x축으로 쓰고 싶은 경우 DataFrame으로 그리세요

# %% [markdown]
# x축에 2, 4, 6만 보이는 이유
# - 데이터는 1~12 모두 존재
# - 눈금(tick)은 자동으로 일부만 표시
# - 즉 x축 값은 모두 사용되지만,글자가 겹치지 않게 일부만 대표로 표시, 자동 눈금(tick) 선택 규칙

# %%
df.plot(x='month', y='sumRn', marker='o')

# %%
df.plot(x='month', y='sumRn', marker='o')
# Out:
# <Axes: xlabel='month'>

# %%
df.plot(x='month' , y='avgTa' , marker='o')

# %%
df.plot(x='month' , y='avgTa' , marker='o')
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## 9. 새로운 열 만들기

# %%
df['일교차']  = df['maxTa'] - df['minTa']

# %%
df['일교차']  = df['maxTa'] - df['minTa']

# %%
df

# %%
df
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs   일교차
# 0       1    광주    1.9   -2.0    6.8    1.2    67.8    1.2   8.8
# 1       1    대전    0.5   -4.1    6.0    0.7    62.8    1.6  10.1
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4   8.6
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3   8.0
# 4       1    제주    6.7    4.0    9.8    1.4    55.4    4.2   5.8
# 5       2    광주    1.1   -2.9    5.7    1.5    64.9    1.5   8.6
# 6       2    대전   -0.1   -5.1    5.8    0.7    56.3    2.1  10.9
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6   9.1
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6   9.2
# 9       2    제주    5.2    2.5    8.1    3.6    58.9    4.4   5.6
# 10      3    광주    9.3    4.3   15.5    2.6    59.6    1.7  11.2
# 11      3    대전    8.6    3.1   14.9    3.1    54.6    2.4  11.8
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7   8.2
# ...

# %% [markdown]
# ## 과제:  여러분이 캠핑하기 좋은 때는 언제일까? 먼저 우리말로 답해보세요!!

# %% [markdown]
# ### 앞에서 배운 것을 data2.csv 파일 ('stnNm'열,즉 지역이 추가됨) 로 복습하며 익혀봅니다

# %% [markdown]
# pandas 라이브러리를 불러와서 pd 로 지정

# %%
import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# 'data2.csv' 파일을 읽어 df 라는 변수에 할당

# %%
df = pd.read_csv('data2.csv')
df

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 1       1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 4       1    제주    6.7    4.0    9.8    1.4    55.4    4.2
# 5       2    광주    1.1   -2.9    5.7    1.5    64.9    1.5
# 6       2    대전   -0.1   -5.1    5.8    0.7    56.3    2.1
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 9       2    제주    5.2    2.5    8.1    3.6    58.9    4.4
# 10      3    광주    9.3    4.3   15.5    2.6    59.6    1.7
# 11      3    대전    8.6    3.1   14.9    3.1    54.6    2.4
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 14      3    제주   11.5    8.3   15.2    4.6    57.2    4.0
# ...

# %% [markdown]
# df의 자료형, 각 열들의 자료형, 행의 수 등의 정보얻기

# %%
df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   60 non-null     int64
#  1   stnNm   60 non-null     object
#  2   avgTa   60 non-null     float64
#  3   minTa   60 non-null     float64
#  4   maxTa   60 non-null     float64
#  5   sumRn   60 non-null     float64
#  6   avgRhm  60 non-null     float64
#  7   avgWs   60 non-null     float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.9+ KB

# %% [markdown]
# df에서 앞의 5개 데이터만을 보려면

# %%
df.head()

# %%
df.head()
# Out:
#    month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0      1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 1      1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# 2      1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3      1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 4      1    제주    6.7    4.0    9.8    1.4    55.4    4.2

# %% [markdown]
# df에서 뒤의 5개 데이터만을 보려면

# %%
df.tail()

# %%
df.tail()
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 55     12    광주    4.6    0.1    9.8    2.4    64.2    1.8
# 56     12    대전    2.3   -2.5    7.6    3.3    63.7    1.7
# 57     12    부산    7.0    2.8   11.9    1.5    48.5    2.5
# 58     12    서울    1.2   -2.9    5.3    3.7    61.3    2.3
# 59     12    제주    9.6    6.1   13.3    1.1    57.8    3.8

# %% [markdown]
# df의 열 들의 목록을 보려면

# %%
df.columns

# %%
df.columns
# Out:
# Index(['month', 'stnNm', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgRhm',
#        'avgWs'],
#       dtype='object')

# %% [markdown]
# df의 수치형 열들의 통계 수치 들을 보려면 describe() 함수를 사용

# %%
df.describe()

# %%
df.describe()
# Out:
#            month      avgTa      minTa      maxTa      sumRn     avgRhm  \
# count  60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean    6.500000  15.458333  11.613333  20.038333   9.475000  65.693333
# std     3.481184   9.477436   9.920471   9.145770  11.177272   9.060846
# min     1.000000  -1.200000  -5.300000   3.900000   0.700000  41.000000
# 25%     3.750000   8.450000   3.525000  13.525000   2.925000  58.975000
# 50%     6.500000  15.950000  11.900000  21.450000   5.700000  66.400000
# 75%     9.250000  24.000000  20.125000  28.350000  11.025000  72.175000
# max    12.000000  29.600000  26.900000  33.200000  69.200000  81.200000
#
#            avgWs
# count  60.000000
# mean    2.438333
# std     0.847347
# min     1.100000
# 25%     1.700000
# 50%     2.300000
# 75%     3.125000
# max     4.400000

# %%
df.columns

# %%
df.columns
# Out:
# Index(['month', 'stnNm', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgRhm',
#        'avgWs'],
#       dtype='object')

# %% [markdown]
# 평균기온 열을 보려면

# %%
df['avgTa']

# %%
df['avgTa']
# Out:
# 0      1.9
# 1      0.5
# 2      4.0
# 3     -0.4
# 4      6.7
# 5      1.1
# 6     -0.1
# 7      2.9
# 8     -1.2
# 9      5.2
# 10     9.3
# 11     8.6
# 12     9.8
# 13     8.0
# 14    11.5
# 15    14.6
# 16    14.4
# 17    14.0
# 18    13.4
# 19    15.4
# 20    18.2
# 21    18.0
# 22    17.4
# 23    17.8
# 24    18.0
# 25    24.0
# 26    24.0
# 27    22.3
# 28    24.0
# 29    23.4
# 30    28.2
# 31    28.3
# 32    27.8
# 33    28.8
# 34    28.3
# 35    27.7
# 36    28.2
# 37    28.4
# 38    28.2
# 39    29.6
# 40    24.1
# 41    23.3
# 42    25.6
# 43    23.4
# 44    27.1
# 45    18.4
# 46    16.9
# 47    19.6
# 48    16.5
# 49    21.9
# 50    10.6
# 51     8.9
# 52    12.9
# 53     9.0
# 54    14.4
# 55     4.6
# 56     2.3
# 57     7.0
# 58     1.2
# 59     9.6
# Name: avgTa, dtype: float64

# %% [markdown]
# 최저기온, 최고기온, 강수량 열을 보려면

# %%
df[['minTa', 'maxTa', 'sumRn']]

# %%
df[['minTa', 'maxTa', 'sumRn']]
# Out:
#     minTa  maxTa  sumRn
# 0    -2.0    6.8    1.2
# 1    -4.1    6.0    0.7
# 2     0.2    8.8    1.1
# 3    -4.1    3.9    1.4
# 4     4.0    9.8    1.4
# 5    -2.9    5.7    1.5
# 6    -5.1    5.8    0.7
# 7    -1.2    7.9    5.3
# 8    -5.3    3.9    1.0
# 9     2.5    8.1    3.6
# 10    4.3   15.5    2.6
# 11    3.1   14.9    3.1
# 12    6.0   14.2    3.7
# 13    3.3   13.6    2.7
# 14    8.3   15.2    4.6
# 15    8.9   21.5    5.6
# 16    7.8   21.5    6.1
# 17   10.4   18.3    7.5
# 18    8.2   19.0    8.6
# 19   11.2   19.7    2.4
# 20   13.6   23.5    8.6
# 21   12.5   23.6    7.8
# 22   14.1   21.4   10.2
# 23   13.3   22.7    8.2
# 24   14.6   22.0    7.4
# 25   19.5   29.0   17.6
# 26   19.2   29.5   23.1
# 27   19.7   25.7   24.4
# 28   20.0   28.5    5.8
# 29   20.2   26.9    5.3
# 30   24.1   33.2   69.2
# 31   24.3   32.9   27.3
# 32   24.9   31.3   34.5
# 33   25.7   32.6   19.6
# 34   25.8   31.3   12.9
# 35   24.3   32.2   30.9
# 36   24.4   32.9    8.1
# ...

# %% [markdown]
# 월, 최고기온 열을 보려면

# %%
df[['month','maxTa' ]]

# %%
df[['month','maxTa' ]]
# Out:
#     month  maxTa
# 0       1    6.8
# 1       1    6.0
# 2       1    8.8
# 3       1    3.9
# 4       1    9.8
# 5       2    5.7
# 6       2    5.8
# 7       2    7.9
# 8       2    3.9
# 9       2    8.1
# 10      3   15.5
# 11      3   14.9
# 12      3   14.2
# 13      3   13.6
# 14      3   15.2
# 15      4   21.5
# 16      4   21.5
# 17      4   18.3
# 18      4   19.0
# 19      4   19.7
# 20      5   23.5
# 21      5   23.6
# 22      5   21.4
# 23      5   22.7
# 24      5   22.0
# 25      6   29.0
# 26      6   29.5
# 27      6   25.7
# 28      6   28.5
# 29      6   26.9
# 30      7   33.2
# 31      7   32.9
# 32      7   31.3
# 33      7   32.6
# 34      7   31.3
# 35      8   32.2
# 36      8   32.9
# 37      8   31.9
# 38      8   31.9
# 39      8   32.9
# 40      9   28.3
# 41      9   27.7
# 42      9   29.6
# 43      9   27.4
# 44      9   30.3
# 45     10   22.9
# 46     10   21.5
# 47     10   23.6
# 48     10   20.4
# 49     10   24.8
# 50     11   16.2
# ...

# %%
df

# %%
df
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 1       1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 4       1    제주    6.7    4.0    9.8    1.4    55.4    4.2
# 5       2    광주    1.1   -2.9    5.7    1.5    64.9    1.5
# 6       2    대전   -0.1   -5.1    5.8    0.7    56.3    2.1
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 9       2    제주    5.2    2.5    8.1    3.6    58.9    4.4
# 10      3    광주    9.3    4.3   15.5    2.6    59.6    1.7
# 11      3    대전    8.6    3.1   14.9    3.1    54.6    2.4
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 14      3    제주   11.5    8.3   15.2    4.6    57.2    4.0
# ...

# %% [markdown]
# 지역 즉 stnNm 열을 보려면

# %%
df['stnNm']

# %%
df['stnNm']
# Out:
# 0     광주
# 1     대전
# 2     부산
# 3     서울
# 4     제주
# 5     광주
# 6     대전
# 7     부산
# 8     서울
# 9     제주
# 10    광주
# 11    대전
# 12    부산
# 13    서울
# 14    제주
# 15    광주
# 16    대전
# 17    부산
# 18    서울
# 19    제주
# 20    광주
# 21    대전
# 22    부산
# 23    서울
# 24    제주
# 25    광주
# 26    대전
# 27    부산
# 28    서울
# 29    제주
# 30    광주
# 31    대전
# 32    부산
# 33    서울
# 34    제주
# 35    광주
# 36    대전
# 37    부산
# 38    서울
# 39    제주
# 40    광주
# 41    대전
# 42    부산
# 43    서울
# 44    제주
# 45    광주
# 46    대전
# 47    부산
# 48    서울
# 49    제주
# 50    광주
# 51    대전
# 52    부산
# 53    서울
# 54    제주
# 55    광주
# 56    대전
# 57    부산
# 58    서울
# 59    제주
# Name: stnNm, dtype: object

# %% [markdown]
# stnNm 열에 들어있는 서로 다른 값을 보려면 unique() 함수 사용

# %%
df['stnNm'].unique()

# %%
df['stnNm'].unique()
# Out:
# array(['광주', '대전', '부산', '서울', '제주'], dtype=object)

# %% [markdown]
# stnNm 열에 들어있는 서로 다른 값들과 그 갯수를 알려면 value_counts() 함수 사용

# %%
df['stnNm'].value_counts()

# %%
df['stnNm'].value_counts()
# Out:
# stnNm
# 광주    12
# 대전    12
# 부산    12
# 서울    12
# 제주    12
# Name: count, dtype: int64

# %% [markdown]
# stnNm 열의 오름차순으로 정렬

# %%
df.sort_values('stnNm')

# %%
df.sort_values('stnNm')
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 40      9    광주   24.1   21.0   28.3   10.4    80.7    1.3
# 20      5    광주   18.2   13.6   23.5    8.6    68.1    1.4
# 30      7    광주   28.2   24.1   33.2   69.2    73.4    1.6
# 15      4    광주   14.6    8.9   21.5    5.6    59.9    1.7
# 55     12    광주    4.6    0.1    9.8    2.4    64.2    1.8
# 25      6    광주   24.0   19.5   29.0   17.6    70.8    1.6
# 10      3    광주    9.3    4.3   15.5    2.6    59.6    1.7
# 50     11    광주   10.6    6.0   16.2    4.1    68.0    1.2
# 35      8    광주   27.7   24.3   32.2   30.9    79.6    1.2
# 5       2    광주    1.1   -2.9    5.7    1.5    64.9    1.5
# 45     10    광주   18.4   15.0   22.9    7.8    77.1    1.1
# 56     12    대전    2.3   -2.5    7.6    3.3    63.7    1.7
# 41      9    대전   23.3   20.1   27.7   16.4    81.2    1.6
# 1       1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# ...

# %% [markdown]
# stnNm 열의 내림차순으로 정렬

# %%
df.sort_values('stnNm',ascending=False)

# %%
df.sort_values('stnNm',ascending=False)
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 59     12    제주    9.6    6.1   13.3    1.1    57.8    3.8
# 9       2    제주    5.2    2.5    8.1    3.6    58.9    4.4
# 44      9    제주   27.1   24.6   30.3   13.1    73.4    2.8
# 39      8    제주   29.6   26.9   32.9    4.2    70.6    2.8
# 34      7    제주   28.3   25.8   31.3   12.9    71.6    3.2
# 29      6    제주   23.4   20.2   26.9    5.3    70.4    2.7
# 24      5    제주   18.0   14.6   22.0    7.4    65.9    2.9
# 19      4    제주   15.4   11.2   19.7    2.4    57.7    3.3
# 14      3    제주   11.5    8.3   15.2    4.6    57.2    4.0
# 54     11    제주   14.4   11.3   18.1    6.6    59.0    3.4
# 49     10    제주   21.9   19.7   24.8    4.2    67.6    3.4
# 4       1    제주    6.7    4.0    9.8    1.4    55.4    4.2
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# ...

# %% [markdown]
# 서울 지역의 데이터만 선택

# %% [markdown]
# 먼저 조건만들기!!

# %%
df['stnNm'] == '서울'

# %%
df['stnNm'] == '서울'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# Name: stnNm, dtype: bool

# %%
df[ df['stnNm'] == '서울' ]

# %%
df[ df['stnNm'] == '서울' ]
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 18      4    서울   13.4    8.2   19.0    8.6    60.5    2.5
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 38      8    서울   28.2   25.3   31.9   17.1    75.6    2.3
# 43      9    서울   23.4   20.3   27.4   23.2    75.4    2.0
# 48     10    서울   16.5   13.1   20.4   10.4    75.5    2.3
# 53     11    서울    9.0    4.6   14.2    3.0    61.3    2.1
# 58     12    서울    1.2   -2.9    5.3    3.7    61.3    2.3

# %%
df_seoul = df[ df['stnNm'] =='서울' ]
df_seoul

# %%
df_seoul = df[ df['stnNm'] =='서울' ]
df_seoul
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 18      4    서울   13.4    8.2   19.0    8.6    60.5    2.5
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 38      8    서울   28.2   25.3   31.9   17.1    75.6    2.3
# 43      9    서울   23.4   20.3   27.4   23.2    75.4    2.0
# 48     10    서울   16.5   13.1   20.4   10.4    75.5    2.3
# 53     11    서울    9.0    4.6   14.2    3.0    61.3    2.1
# 58     12    서울    1.2   -2.9    5.3    3.7    61.3    2.3

# %% [markdown]
# 서울 지역의 최고기온 열을 검색

# %%
df_seoul['maxTa']

# %%
df_seoul['maxTa']
# Out:
# 3      3.9
# 8      3.9
# 13    13.6
# 18    19.0
# 23    22.7
# 28    28.5
# 33    32.6
# 38    31.9
# 43    27.4
# 48    20.4
# 53    14.2
# 58     5.3
# Name: maxTa, dtype: float64

# %% [markdown]
# 서울 지역의 월, 평균기온 열을 검색

# %%
df_seoul[['month' , 'avgTa']]

# %%
df_seoul[['month' , 'avgTa']]
# Out:
#     month  avgTa
# 3       1   -0.4
# 8       2   -1.2
# 13      3    8.0
# 18      4   13.4
# 23      5   17.8
# 28      6   24.0
# 33      7   28.8
# 38      8   28.2
# 43      9   23.4
# 48     10   16.5
# 53     11    9.0
# 58     12    1.2

# %% [markdown]
# 다른 방법으로 해볼까요

# %%
df[df['stnNm'] == '서울']

# %%
df[df['stnNm'] == '서울']
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 18      4    서울   13.4    8.2   19.0    8.6    60.5    2.5
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 38      8    서울   28.2   25.3   31.9   17.1    75.6    2.3
# 43      9    서울   23.4   20.3   27.4   23.2    75.4    2.0
# 48     10    서울   16.5   13.1   20.4   10.4    75.5    2.3
# 53     11    서울    9.0    4.6   14.2    3.0    61.3    2.1
# 58     12    서울    1.2   -2.9    5.3    3.7    61.3    2.3

# %%
df[ df['stnNm'] == '서울' ]['avgTa']

# %%
df[ df['stnNm'] == '서울' ]['avgTa']
# Out:
# 3     -0.4
# 8     -1.2
# 13     8.0
# 18    13.4
# 23    17.8
# 28    24.0
# 33    28.8
# 38    28.2
# 43    23.4
# 48    16.5
# 53     9.0
# 58     1.2
# Name: avgTa, dtype: float64

# %% [markdown]
# 서울 지역의 월과 평균기온 검색

# %%
df[df['stnNm'] == '서울'][['month' , 'avgTa']]

# %%
df[df['stnNm'] == '서울'][['month' , 'avgTa']]
# Out:
#     month  avgTa
# 3       1   -0.4
# 8       2   -1.2
# 13      3    8.0
# 18      4   13.4
# 23      5   17.8
# 28      6   24.0
# 33      7   28.8
# 38      8   28.2
# 43      9   23.4
# 48     10   16.5
# 53     11    9.0
# 58     12    1.2

# %% [markdown]
# 부산 지역의 데이터를 선택하세요

# %%
df['stnNm'] == '부산'

# %%
df['stnNm'] == '부산'
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# 51    False
# 52     True
# 53    False
# 54    False
# 55    False
# 56    False
# 57     True
# 58    False
# 59    False
# Name: stnNm, dtype: bool

# %%
df[ df['stnNm'] == '부산']

# %%
df[ df['stnNm'] == '부산']
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 17      4    부산   14.0   10.4   18.3    7.5    62.2    3.8
# 22      5    부산   17.4   14.1   21.4   10.2    71.4    3.2
# 27      6    부산   22.3   19.7   25.7   24.4    77.4    3.3
# 32      7    부산   27.8   24.9   31.3   34.5    73.3    3.1
# 37      8    부산   28.4   25.8   31.9   17.6    77.7    3.3
# 42      9    부산   25.6   23.1   29.6    3.6    74.3    3.0
# 47     10    부산   19.6   17.0   23.6    8.4    71.3    2.5
# 52     11    부산   12.9    8.7   17.9    5.1    52.8    2.9
# 57     12    부산    7.0    2.8   11.9    1.5    48.5    2.5

# %%
df_busan = df[ df['stnNm'] == '부산']
df_busan

# %%
df_busan = df[ df['stnNm'] == '부산']
df_busan
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 17      4    부산   14.0   10.4   18.3    7.5    62.2    3.8
# 22      5    부산   17.4   14.1   21.4   10.2    71.4    3.2
# 27      6    부산   22.3   19.7   25.7   24.4    77.4    3.3
# 32      7    부산   27.8   24.9   31.3   34.5    73.3    3.1
# 37      8    부산   28.4   25.8   31.9   17.6    77.7    3.3
# 42      9    부산   25.6   23.1   29.6    3.6    74.3    3.0
# 47     10    부산   19.6   17.0   23.6    8.4    71.3    2.5
# 52     11    부산   12.9    8.7   17.9    5.1    52.8    2.9
# 57     12    부산    7.0    2.8   11.9    1.5    48.5    2.5

# %% [markdown]
# 부산 지역의 월, 최저기온, 최고기온, 강수량 정보를 구하시오

# %%
df_busan[['month', 'minTa', 'maxTa', 'sumRn']]

# %%
df_busan[['month', 'minTa', 'maxTa', 'sumRn']]
# Out:
#     month  minTa  maxTa  sumRn
# 2       1    0.2    8.8    1.1
# 7       2   -1.2    7.9    5.3
# 12      3    6.0   14.2    3.7
# 17      4   10.4   18.3    7.5
# 22      5   14.1   21.4   10.2
# 27      6   19.7   25.7   24.4
# 32      7   24.9   31.3   34.5
# 37      8   25.8   31.9   17.6
# 42      9   23.1   29.6    3.6
# 47     10   17.0   23.6    8.4
# 52     11    8.7   17.9    5.1
# 57     12    2.8   11.9    1.5

# %%
df_busan.plot(x='month', y='sumRn')

# %%
df_busan.plot(x='month', y='sumRn')
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## 과제:  여러분이 캠핑하기 좋은 때는 언제일까?
# ### 앞에서 우리말로 답한것을 문제로 써본 후 셀에 코딩해보세요 (여러분이 생각한 것이 답)

# %%
camping_df = df[(df['avgTa'] >= 15) & (df['avgTa'] <= 25) & (df['sumRn'] < 10)]

# %%
camping_df
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs   일교차
# 19      4    제주   15.4   11.2   19.7    2.4    57.7    3.3   8.5
# 20      5    광주   18.2   13.6   23.5    8.6    68.1    1.4   9.9
# 21      5    대전   18.0   12.5   23.6    7.8    65.1    1.9  11.1
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3   9.4
# 24      5    제주   18.0   14.6   22.0    7.4    65.9    2.9   7.4
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3   8.5
# 29      6    제주   23.4   20.2   26.9    5.3    70.4    2.7   6.7
# 45     10    광주   18.4   15.0   22.9    7.8    77.1    1.1   7.9
# 47     10    부산   19.6   17.0   23.6    8.4    71.3    2.5   6.6
# 49     10    제주   21.9   19.7   24.8    4.2    67.6    3.4   5.1

# %%
df[(df['stnNm'] == '서울') & (df['month'] == 5)]
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs  일교차
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3  9.4

# %%
이렇게 적는게 맞는지 잘 모르겠지만 앞으로 더 복잡한 조건도 자유자재로 다뤄보고 싶습니다.
