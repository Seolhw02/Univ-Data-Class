# %% [markdown]
# ## 서울시 상권 데이터 분석
#
# ### 학습 목표
#
# - CSV 파일을 불러와서 데이터를 살펴본다
# - 데이터를 원하는 조건으로 걸러내고 집계한다
# - 그래프를 그려서 데이터를 눈으로 확인한다
#
# > 파일: `서울상권.csv` (같은 폴더 안에 있어야 합니다)
# > 라이브러리: pandas, matplotlib, seaborn

# %%
import pandas as pd          
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %% [markdown]
# ``` python
# import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # Windows 기본 한글 폰트
# # matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac 사용자는 이 줄 사용
# matplotlib.rcParams['axes.unicode_minus'] = False     # 마이너스 부호 깨짐 방지
# ```

# %% [markdown]
# ---
#
# ## PART 2. 데이터 불러오기
#
# ### CSV 파일이란?
#
# > CSV = **C**omma-**S**eparated **V**alues (쉼표로 구분된 값)
#
# ### DataFrame 이란?
#
# > pandas에서 표(테이블) 형태의 데이터를 **DataFrame** 이라고 부릅니다.
# > - **행(row)**: 하나의 상가·업소 정보
# > - **열(column)**: 상호명, 업종 등 항목
# > - **인덱스(index)**: 행 번호 (0부터 시작)

# %%
df1 = pd.read_csv('서울상권.csv')

# %%
df = df1.copy()

# %% [markdown]
# ---
#
# ## PART 3. 데이터 살펴보기 (기본 탐색)
#
# > 데이터를 받으면 제일 먼저 **어떻게 생긴 데이터인지** 파악해야 합니다.
#
# ### 탐색 명령어 모음
#
# | 명령어 | 의미 |
# |--------|------|
# | `df.head()` | 앞에서 5행 보기 |
# | `df.tail()` | 뒤에서 5행 보기 |
# | `df.shape` | (행 수, 열 수) 확인 |
# | `df.columns` | 전체 컬럼명 목록 |
# | `df.info()` | 컬럼별 타입과 결측치 요약 |
# | `df.describe()` | 숫자 컬럼의 통계 요약 | # include='all'

# %%
df.head(3)
# Out:
#                  상가업소번호      상호명  지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명    시도명 시군구명  \
# 0  MA010120220804265295  60계치킨암사  선사점       음식    기타 간이       치킨  서울특별시  강동구
# 1  MA010120220809658173   성심인력공사  NaN  시설관리·임대    고용 알선   고용 알선업  서울특별시  용산구
# 2  MA010120220808205276      칸토빈  NaN       음식    비알코올        카페  서울특별시  강서구
#
#    행정동명               도로명주소  신우편번호  층정보          경도         위도
# 0  암사2동   서울특별시 강동구 상암로3길 8   5241    1  127.126859  37.550810
# 1   남영동  서울특별시 용산구 한강대로 385   4320  NaN  126.972240  37.552803
# 2   공항동   서울특별시 강서구 방화동로 30   7619    1  126.810493  37.563548

# %%
df.shape
# Out:
# (534978, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 534978 entries, 0 to 534977
# Data columns (total 14 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상가업소번호    534978 non-null  str
#  1   상호명       534978 non-null  str
#  2   지점명       47936 non-null   str
#  3   상권업종대분류명  534978 non-null  str
#  4   상권업종중분류명  534978 non-null  str
#  5   상권업종소분류명  534978 non-null  str
#  6   시도명       534978 non-null  str
#  7   시군구명      534978 non-null  str
#  8   행정동명      534978 non-null  str
#  9   도로명주소     534978 non-null  str
#  10  신우편번호     534978 non-null  int64
#  11  층정보       346988 non-null  str
#  12  경도        534978 non-null  float64
#  13  위도        534978 non-null  float64
# dtypes: float64(2), int64(1), str(11)
# memory usage: 57.1 MB

# %%
df.describe()
# Out:
#                신우편번호             경도             위도
# count  534978.000000  534978.000000  534978.000000
# mean     5344.210325     126.993058      37.540650
# std      2086.710363       0.082605       0.047720
# min      1000.000000     126.768186      37.430456
# 25%      3785.000000     126.922493      37.501818
# 50%      5565.000000     127.010064      37.536579
# 75%      6964.000000     127.052791      37.568572
# max      8866.000000     127.182653      37.692604

# %%
df.describe(include='all')
# Out:
#                       상가업소번호     상호명    지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# count                 534978  534978  47936   534978   534978   534978
# unique                534978  425063    858       10       75      247
# top     MA010120220804265295   업소명없음    코리아       음식       한식   백반/한정식
# freq                       1     717   5812   135884    50770    26376
# mean                     NaN     NaN    NaN      NaN      NaN      NaN
# std                      NaN     NaN    NaN      NaN      NaN      NaN
# min                      NaN     NaN    NaN      NaN      NaN      NaN
# 25%                      NaN     NaN    NaN      NaN      NaN      NaN
# 50%                      NaN     NaN    NaN      NaN      NaN      NaN
# 75%                      NaN     NaN    NaN      NaN      NaN      NaN
# max                      NaN     NaN    NaN      NaN      NaN      NaN
#
#            시도명    시군구명    행정동명             도로명주소          신우편번호     층정보  \
# count   534978  534978  534978            534978  534978.000000  346988
# unique       1      25     427            156448            NaN     201
# top      서울특별시     강남구    역삼1동  서울특별시 송파구 충민로 66            NaN       1
# freq    534978   64123   13380              1159            NaN  175319
# mean       NaN     NaN     NaN               NaN    5344.210325     NaN
# std        NaN     NaN     NaN               NaN    2086.710363     NaN
# min        NaN     NaN     NaN               NaN    1000.000000     NaN
# 25%        NaN     NaN     NaN               NaN    3785.000000     NaN
# 50%        NaN     NaN     NaN               NaN    5565.000000     NaN
# 75%        NaN     NaN     NaN               NaN    6964.000000     NaN
# max        NaN     NaN     NaN               NaN    8866.000000     NaN
#
#                    경도             위도
# count   534978.000000  534978.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean       126.993058      37.540650
# std          0.082605       0.047720
# min        126.768186      37.430456
# 25%        126.922493      37.501818
# 50%        127.010064      37.536579
# 75%        127.052791      37.568572
# max        127.182653      37.692604

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '시도명',
#        '시군구명', '행정동명', '도로명주소', '신우편번호', '층정보', '경도', '위도'],
#       dtype='str')

# %% [markdown]
# ---
#
# ## PART 4. 필요한 컬럼만 골라서 사용하기
#
# > 모든 컬럼 전부를 다 쓸 필요는 없습니다.
# > 분석 목적에 맞는 컬럼만 골라서 쓰면 코드가 훨씬 간단해집니다!
#
# ### 컬럼 선택 방법
#
# ```python
#
# 1) 컬럼 1개 선택 → Series 반환
# df['컬럼명']
#
# 2) 컬럼 여러 개 선택 → DataFrame 반환
# df[['컬럼명1', '컬럼명2', '컬럼명3']]
# ```
#
# > **Series**: 1차원 데이터 (컬럼 1개만 뽑았을 때)
# > **DataFrame**: 2차원 데이터 (컬럼 여러 개)

# %% [markdown]
# #### 컬럼 1개 선택 (Series)
# > df['컬럼명'] → 해당 컬럼의 값들을 Series로 반환

# %%
df['상권업종대분류명']
# Out:
# 0              음식
# 1         시설관리·임대
# 2              음식
# 3          예술·스포츠
# 4              소매
#            ...
# 534973         소매
# 534974         음식
# 534975         음식
# 534976         음식
# 534977         소매
# Name: 상권업종대분류명, Length: 534978, dtype: str

# %% [markdown]
# #### 컬럼 여러 개 선택 (DataFrame)
# > 바깥쪽 [    ] 는 인덱싱, 안쪽 [      ] 는 리스트  → df[리스트] 형태

# %%
df[[  '상권업종대분류명', '상권업종중분류명', '상권업종소분류명'      ]]
# Out:
#        상권업종대분류명   상권업종중분류명          상권업종소분류명
# 0            음식      기타 간이                치킨
# 1       시설관리·임대      고용 알선            고용 알선업
# 2            음식      비알코올                 카페
# 3        예술·스포츠     유원지·오락               노래방
# 4            소매  시계·귀금속 소매        시계/귀금속 소매업
# ...         ...        ...               ...
# 534973       소매   기타 상품 소매  그 외 기타 상품 전문 소매업
# 534974       음식         한식          곱창 전골/구이
# 534975       음식         한식           국/탕/찌개류
# 534976       음식      비알코올                 카페
# 534977       소매     장식품 소매              기념품점
#
# [534978 rows x 3 columns]

# %% [markdown]
# ---
#
# ## PART 5. 빠진 값(결측치) 처리하기
#
# ### 결측치(Missing Value)란?
#
# > 데이터가 **비어있는 경우**를 결측치라고 합니다.
# > `NaN` (Not a Number) 으로 표시됩니다.
#
# ### 왜 처리해야 할까요?
#
# - 결측치가 있으면 계산이 틀려질 수 있고 오류가 날 수 있습니다
#
# ### 결측치 처리 방법
#
# | 방법 | 코드 | 언제 쓰나 |
# |------|------|----------|
# | 확인 | `df.isnull().sum()` | 결측치가 몇 개인지 확인 |
# | 제거 | `df.dropna()` | 결측치 있는 행 통째로 제거 |
# |      | `df.dropna(subset=['컬럼명'])` | 해당 컬럼에 결측치가 있는 행만 제거 |
# | 채우기 | `df.fillna(값)` | 결측치를 특정 값으로 채우기 |

# %%
df.isnull().sum()
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명         487042
# 상권업종대분류명         0
# 상권업종중분류명         0
# 상권업종소분류명         0
# 시도명              0
# 시군구명             0
# 행정동명             0
# 도로명주소            0
# 신우편번호            0
# 층정보         187990
# 경도               0
# 위도               0
# dtype: int64

# %% [markdown]
# ---
#
# ## PART 6. 조건에 맞는 데이터만 골라내기 (필터링)
#
# > 전체 데이터 중 원하는 행만 골라내는 것을 **필터링** 이라고 합니다.
#
# ### 기본 문법
#
# ```python
# df[조건식]
# ```
#
# ### 비교 연산자
#
# > ==, !=, >, >=, <, <=
#
# ### 다중 조건
#
# | 기호 | 의미 | 예시 |
# |------|------|------|
# | `&` | AND (둘 다 참) | `(조건1) & (조건2)` |
# | `\|` | OR (하나라도 참) | `(조건1) \| (조건2)` |
# | `~` | NOT (반대) | `~조건` |
#
# > **주의**: 다중 조건은 반드시 각 조건을 `()` 괄호로 감싸야 합니다!

# %%
df.columns

# %% [markdown]
# 문제 1 : '강남구'인 데이터만 선택

# %%
df[ df['시군구명'] == '강남구']
# Out:
#                       상가업소번호            상호명  지점명 상권업종대분류명     상권업종중분류명  \
# 11      MA010120220804484713       세마스포츠마케팅  NaN  시설관리·임대    기타 사업 서비스
# 16      MA010120220804119412           솔잎약국  NaN       소매    의약·화장품 소매
# 45      MA010120220808263588    강남주얼리창업아카데미  NaN    과학·기술    본사·경영 컨설팅
# 63      MA010120220810251143            타카라  NaN       음식           일식
# 65      MA010120220806625053       에이에이치이엔씨  NaN    과학·기술       기술 서비스
# ...                      ...            ...  ...      ...          ...
# 534904  MA0106202511A0047254       휴먼메이드압구정  NaN       소매  섬유·의복·신발 소매
# 534914  MA0106202511A0652755        앵콜노래연습장  NaN   예술·스포츠       유원지·오락
# 534923  MA0106202511A0498693         윤대감빈대떡  NaN       음식           한식
# 534929  MA0106202511A1958658           미소담은  NaN       소매    의약·화장품 소매
# 534933  MA0106202511A1037541  우리동네국민상회강남세곡점  NaN       소매     기타 상품 소매
#
#                  상권업종소분류명    시도명 시군구명  행정동명                   도로명주소  신우편번호  \
# 11      전시/컨벤션/행사 대행 서비스업  서울특별시  강남구  역삼1동    서울특별시 강남구 테헤란로25길 47   6126
# 16                     약국  서울특별시  강남구  개포3동       서울특별시 강남구 개포로 615   6335
# 45                경영 컨설팅업  서울특별시  강남구  압구정동    서울특별시 강남구 압구정로30길 60   6025
# 63                일식 회/초밥  서울특별시  강남구  압구정동    서울특별시 강남구 압구정로48길 15   6018
# 65        건축 설계 및 관련 서비스업  서울특별시  강남구   세곡동    서울특별시 강남구 자곡로 174-10   6373
# ...                   ...    ...  ...   ...                     ...    ...
# 534904          기타 의류 소매업  서울특별시  강남구  압구정동  서울특별시 강남구 선릉로157길 20-8   6018
# 534914                노래방  서울특별시  강남구  역삼1동     서울특별시 강남구 봉은사로2길 24   6123
# 534923              전/부침개  서울특별시  강남구  역삼1동    서울특별시 강남구 강남대로84길 15   6232
# 534929            화장품 소매업  서울특별시  강남구   청담동    서울특별시 강남구 도산대로81길 23   6011
# 534933   그 외 기타 상품 전문 소매업  서울특별시  강남구   세곡동    서울특별시 강남구 헌릉로569길 13   6376
#
#         층정보          경도         위도
# 11      NaN  127.034404  37.503571
# 16      NaN  127.075593  37.492659
# 45        4  127.028858  37.523449
# 63        1  127.037243  37.527528
# 65      NaN  127.103010  37.472671
# ...     ...         ...        ...
# 534904  NaN  127.038543  37.526617
# 534914  NaN  127.025887  37.503087
# 534923  NaN  127.029764  37.497013
# 534929  NaN  127.047231  37.525911
# 534933  NaN  127.100040  37.466817
#
# [64123 rows x 14 columns]

# %% [markdown]
# 문제 2: 상권업종대분류명이 '음식' 인 데이터만 선택

# %%
df[ df['상권업종대분류명'] =='음식']
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류명 상권업종중분류명   상권업종소분류명  \
# 0       MA010120220804265295  60계치킨암사  선사점       음식    기타 간이         치킨
# 2       MA010120220808205276      칸토빈  NaN       음식    비알코올          카페
# 8       MA010120220809640417    솜노래팡팡  NaN       음식       주점      요리 주점
# 15      MA010120220812811919  읏듬돈생삼겹살  NaN       음식       한식  돼지고기 구이/찜
# 36      MA010120220809620318   동원기사식당  NaN       음식       한식     백반/한정식
# ...                      ...      ...  ...      ...      ...        ...
# 534971  MA0106202511A0686689      오부찌  NaN       음식       한식     백반/한정식
# 534972  MA0106202511A1878996  생각과생각사이  NaN       음식       한식     백반/한정식
# 534974  MA0106202511A2270156    연막창건대  직영점       음식       한식   곱창 전골/구이
# 534975  MA0106202511A0034578     하루곰탕  NaN       음식       한식    국/탕/찌개류
# 534976  MA0106202511A2056843     만월다방  한강점       음식    비알코올          카페
#
#           시도명  시군구명   행정동명                  도로명주소  신우편번호  층정보          경도  \
# 0       서울특별시   강동구   암사2동      서울특별시 강동구 상암로3길 8   5241    1  127.126859
# 2       서울특별시   강서구    공항동      서울특별시 강서구 방화동로 30   7619    1  126.810493
# 8       서울특별시   서초구   서초3동   서울특별시 서초구 서초대로50길 75   6650    1  127.013852
# 15      서울특별시   성북구    석관동    서울특별시 성북구 화랑로40길 43   2781    1  127.064015
# 36      서울특별시   양천구   신정7동    서울특별시 양천구 목동남로 64-1   8101    1  126.866492
# ...       ...   ...    ...                    ...    ...  ...         ...
# 534971  서울특별시   송파구   문정2동     서울특별시 송파구 송파대로 167   5855  NaN  127.120755
# 534972  서울특별시   용산구  용산2가동       서울특별시 용산구 신흥로 11   4338  NaN  126.986332
# 534974  서울특별시   광진구    화양동   서울특별시 광진구 동일로24길 101   5016  NaN  127.070563
# 534975  서울특별시  동대문구   장안2동  서울특별시 동대문구 사가정로25길 21   2516  NaN  127.070371
# 534976  서울특별시   마포구    서강동      서울특별시 마포구 토정로 130   4081  NaN  126.925497
#
#                위도
# 0       37.550810
# 2       37.563548
# 8       37.489862
# 15      37.613579
# 36      37.509645
# ...           ...
# 534971  37.484557
# 534972  37.539624
# 534974  37.542406
# 534975  37.579807
# 534976  37.545062
#
# [135884 rows x 14 columns]

# %% [markdown]
# 음식에서 상권업종중분류명 검색

# %%
df[ df['상권업종대분류명'] =='음식']['상권업종중분류명'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='상권업종중분류명'>

# %%
df_food =df[ df['상권업종대분류명'] =='음식']
df_food['상권업종중분류명'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# 문제 2-3: 상권업종중분류명이 한식인 경우 상권업종소분류명 ?

# %%
df[ df['상권업종중분류명']=='한식' ]['상권업종소분류명'].value_counts()
# Out:
# 상권업종소분류명
# 백반/한정식         26376
# 돼지고기 구이/찜       7682
# 국/탕/찌개류         4571
# 국수/칼국수          2843
# 횟집              1955
# 해산물 구이/찜        1693
# 곱창 전골/구이        1271
# 닭/오리고기 구이/찜     1195
# 족발/보쌈           1156
# 소고기 구이/찜         901
# 냉면/밀면            584
# 기타 한식 음식점        272
# 전/부침개            189
# 복 요리 전문           82
# Name: count, dtype: int64

# %%
df[ df['상권업종중분류명']=='한식' ]['상권업종소분류명'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 문제 3: 상호명에 '치킨' 이 들어가는 업소 찾기

# %%
df[df['상호명'].str.contains('치킨') ]
# Out:
#                       상가업소번호        상호명     지점명 상권업종대분류명 상권업종중분류명  상권업종소분류명  \
# 0       MA010120220804265295    60계치킨암사     선사점       음식    기타 간이        치킨
# 435     MA010120220813331151  굽네치킨마포도화점     NaN       음식    기타 간이        치킨
# 556     MA010120220813742641  아이러브피자&치킨     NaN       음식    기타 간이        치킨
# 577     MA010120220800265091       치킨뱅이     NaN       음식    기타 간이        치킨
# 1200    MA010120220811798444  치킨을사랑한떡볶이     강동점       음식    기타 간이  김밥/만두/분식
# ...                      ...        ...     ...      ...      ...       ...
# 534513  MA0106202511A1947495       자담치킨  금천구청역점       음식    기타 간이        치킨
# 534569  MA0106202511A1415825       교촌치킨     고척점       음식    기타 간이        치킨
# 534732  MA0106202511A2381493   파자나라치킨공주     목동점       음식    기타 간이        치킨
# 534871  MA0106202511A0569154   처갓집양념치킨북     아현점       음식    기타 간이        치킨
# 534931  MA0106202511A0505177   60계치킨서울우     장산점       음식    기타 간이        치킨
#
#           시도명  시군구명  행정동명                 도로명주소  신우편번호  층정보          경도  \
# 0       서울특별시   강동구  암사2동     서울특별시 강동구 상암로3길 8   5241    1  127.126859
# 435     서울특별시   마포구   도화동     서울특별시 마포구 도화4길 23   4169    1  126.951164
# 556     서울특별시   은평구  신사1동   서울특별시 은평구 증산로21길 10   3450    1  126.913794
# 577     서울특별시   용산구   남영동    서울특별시 용산구 한강대로 399   4320  NaN  126.972352
# 1200    서울특별시   강동구  성내3동   서울특별시 강동구 양재대로87길 5   5405    2  127.134588
# ...       ...   ...   ...                   ...    ...  ...         ...
# 534513  서울특별시   금천구  독산1동    서울특별시 금천구 시흥대로 291   8608  NaN  126.897244
# 534569  서울특별시   구로구  고척2동   서울특별시 구로구 경인로33길 89   8235  NaN  126.850435
# 534732  서울특별시   양천구   목4동  서울특별시 양천구 목동중앙로3길 59   7960  NaN  126.867857
# 534871  서울특별시  서대문구   충현동  서울특별시 서대문구 경기대로9길 81   3752  NaN  126.959705
# 534931  서울특별시   양천구  신월5동   서울특별시 양천구 화곡로13길 13   7903  NaN  126.833453
#
#                위도
# 0       37.550810
# 435     37.540885
# 556     37.595996
# 577     37.553957
# 1200    37.525285
# ...           ...
# 534513  37.460553
# 534569  37.501787
# 534732  37.537497
# 534871  37.564423
# 534931  37.540553
#
# [2818 rows x 14 columns]

# %% [markdown]
# 문제 4: 종로구, 중구, 동대문구 세 곳 중 하나인 데이터만 선택

# %%
df[ df['시군구명'].isin( [  '종로구', '중구', '동대문구' ] )]
# Out:
#                       상가업소번호           상호명  지점명 상권업종대분류명     상권업종중분류명  \
# 4       MA010120220810170381         금빛주얼리  NaN       소매    시계·귀금속 소매
# 14      MA010120220803494326           DGI  NaN       소매  섬유·의복·신발 소매
# 18      MA010120220803750708  우성그린공인중개사사무소  NaN      부동산      부동산 서비스
# 22      MA010120220813245508          요꼬양말  NaN       소매  섬유·의복·신발 소매
# 28      MA010120220800002811       PRO.COM  NaN    수리·개인      통신장비 수리
# ...                      ...           ...  ...      ...          ...
# 534955  MA0106202511A0356826          아트모아  NaN       소매  섬유·의복·신발 소매
# 534966  MA0106202511A0711978           몽중헌  광화문       음식           중식
# 534969  MA0106202511A1075943            곧은  NaN       음식           한식
# 534975  MA0106202511A0034578          하루곰탕  NaN       음식           한식
# 534977  MA0106202511A2286838      에이치아이디자인  NaN       소매       장식품 소매
#
#             상권업종소분류명    시도명  시군구명         행정동명                  도로명주소  신우편번호  \
# 4         시계/귀금속 소매업  서울특별시   종로구  종로1.2.3.4가동    서울특별시 종로구 돈화문로10길 2   3138
# 14       액세서리/잡화 소매업  서울특별시    중구          회현동        서울특별시 중구 소공로 58   4535
# 18        부동산 중개/대리업  서울특별시  동대문구        답십리2동     서울특별시 동대문구 한천로 145   2535
# 22        유아용 의류 소매업  서울특별시    중구          회현동    서울특별시 중구 남대문시장8길 13   4529
# 28      핸드폰/통신장비 수리업  서울특별시   종로구  종로1.2.3.4가동     서울특별시 종로구 창경궁로 109   3137
# ...              ...    ...   ...          ...                    ...    ...
# 534955        가발 소매업  서울특별시    중구          광희동      서울특별시 중구 청계천로 274   4563
# 534966           중국집  서울특별시   종로구          사직동    서울특별시 종로구 새문안로5길 31   3173
# 534969        백반/한정식  서울특별시   종로구  종로1.2.3.4가동   서울특별시 종로구 삼일대로17길 51   3189
# 534975       국/탕/찌개류  서울특별시  동대문구         장안2동  서울특별시 동대문구 사가정로25길 21   2516
# 534977          기념품점  서울특별시    중구          광희동     서울특별시 중구 동호로33길 24   4547
#
#         층정보          경도         위도
# 4         1  126.991861  37.572331
# 14        1  126.981846  37.560662
# 18        1  127.066710  37.574006
# 22      NaN  126.978643  37.559869
# 28        3  126.997079  37.572349
# ...     ...         ...        ...
# 534955  NaN  127.008048  37.569430
# 534966  NaN  126.974360  37.572977
# 534969  NaN  126.984674  37.569078
# 534975  NaN  127.070371  37.579807
# 534977  NaN  127.000860  37.565655
#
# [61594 rows x 14 columns]

# %% [markdown]
# 문제 5: 강남구의 음식 업종인 상가 찾기

# %%
df[ (df['시군구명'] =='강남구')  &  ( df['상권업종대분류명'] == '음식')]
# Out:
#                       상가업소번호           상호명   지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 63      MA010120220810251143           타카라   NaN       음식       일식  일식 회/초밥
# 476     MA010120220803319560         터닝포인트   NaN       음식    기타 간이       피자
# 562     MA010120220800606553           에이치   NaN       음식      서양식      경양식
# 779     MA010120220803390251          라플란드   NaN       음식      서양식      경양식
# 819     MA010120220813266322             훈   NaN       음식       일식  일식 회/초밥
# ...                      ...           ...   ...      ...      ...      ...
# 534862  MA0106202511A1601966       까만미소의하루   NaN       음식    비알코올        카페
# 534870  MA0106202511A1128607             탉   NaN       음식       한식   백반/한정식
# 534885  MA0106202511A1654833        마이니치라멘  선정릉점       음식       일식  일식 면 요리
# 534888  MA0106202511A0145239  에스에이치케이인터내셔널   NaN       음식      서양식      경양식
# 534923  MA0106202511A0498693        윤대감빈대떡   NaN       음식       한식    전/부침개
#
#           시도명 시군구명  행정동명                 도로명주소  신우편번호  층정보          경도  \
# 63      서울특별시  강남구  압구정동  서울특별시 강남구 압구정로48길 15   6018    1  127.037243
# 476     서울특별시  강남구  역삼2동   서울특별시 강남구 테헤란로44길 8   6210    5  127.044446
# 562     서울특별시  강남구  논현2동    서울특별시 강남구 봉은사로 319   6103    1  127.041826
# 779     서울특별시  강남구  삼성2동  서울특별시 강남구 봉은사로63길 11   6097    4  127.046895
# 819     서울특별시  강남구  대치2동   서울특별시 강남구 삼성로84길 28   6184    1  127.059840
# ...       ...  ...   ...                   ...    ...  ...         ...
# 534862  서울특별시  강남구  역삼1동  서울특별시 강남구 테헤란로20길 20   6235  NaN  127.034514
# 534870  서울특별시  강남구  압구정동  서울특별시 강남구 언주로168길 24   6020  NaN  127.035545
# 534885  서울특별시  강남구  삼성2동   서울특별시 강남구 봉은사로63길 7   6097  NaN  127.046962
# 534888  서울특별시  강남구  도곡2동   서울특별시 강남구 논현로28길 14   6302  NaN  127.043970
# 534923  서울특별시  강남구  역삼1동  서울특별시 강남구 강남대로84길 15   6232  NaN  127.029764
#
#                위도
# 63      37.527528
# 476     37.502333
# 562     37.509939
# 779     37.512135
# 819     37.505759
# ...           ...
# 534862  37.498363
# 534870  37.525915
# 534885  37.511937
# 534888  37.482709
# 534923  37.497013
#
# [12346 rows x 14 columns]

# %%
cond1 =  df['시군구명'] =='강남구'

# %%
cond2 =  df['상권업종대분류명'] == '음식'

# %%
df[ cond1   &  cond2    ]
# Out:
#                       상가업소번호           상호명   지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 63      MA010120220810251143           타카라   NaN       음식       일식  일식 회/초밥
# 476     MA010120220803319560         터닝포인트   NaN       음식    기타 간이       피자
# 562     MA010120220800606553           에이치   NaN       음식      서양식      경양식
# 779     MA010120220803390251          라플란드   NaN       음식      서양식      경양식
# 819     MA010120220813266322             훈   NaN       음식       일식  일식 회/초밥
# ...                      ...           ...   ...      ...      ...      ...
# 534862  MA0106202511A1601966       까만미소의하루   NaN       음식    비알코올        카페
# 534870  MA0106202511A1128607             탉   NaN       음식       한식   백반/한정식
# 534885  MA0106202511A1654833        마이니치라멘  선정릉점       음식       일식  일식 면 요리
# 534888  MA0106202511A0145239  에스에이치케이인터내셔널   NaN       음식      서양식      경양식
# 534923  MA0106202511A0498693        윤대감빈대떡   NaN       음식       한식    전/부침개
#
#           시도명 시군구명  행정동명                 도로명주소  신우편번호  층정보          경도  \
# 63      서울특별시  강남구  압구정동  서울특별시 강남구 압구정로48길 15   6018    1  127.037243
# 476     서울특별시  강남구  역삼2동   서울특별시 강남구 테헤란로44길 8   6210    5  127.044446
# 562     서울특별시  강남구  논현2동    서울특별시 강남구 봉은사로 319   6103    1  127.041826
# 779     서울특별시  강남구  삼성2동  서울특별시 강남구 봉은사로63길 11   6097    4  127.046895
# 819     서울특별시  강남구  대치2동   서울특별시 강남구 삼성로84길 28   6184    1  127.059840
# ...       ...  ...   ...                   ...    ...  ...         ...
# 534862  서울특별시  강남구  역삼1동  서울특별시 강남구 테헤란로20길 20   6235  NaN  127.034514
# 534870  서울특별시  강남구  압구정동  서울특별시 강남구 언주로168길 24   6020  NaN  127.035545
# 534885  서울특별시  강남구  삼성2동   서울특별시 강남구 봉은사로63길 7   6097  NaN  127.046962
# 534888  서울특별시  강남구  도곡2동   서울특별시 강남구 논현로28길 14   6302  NaN  127.043970
# 534923  서울특별시  강남구  역삼1동  서울특별시 강남구 강남대로84길 15   6232  NaN  127.029764
#
#                위도
# 63      37.527528
# 476     37.502333
# 562     37.509939
# 779     37.512135
# 819     37.505759
# ...           ...
# 534862  37.498363
# 534870  37.525915
# 534885  37.511937
# 534888  37.482709
# 534923  37.497013
#
# [12346 rows x 14 columns]

# %% [markdown]
# ---
#
# ## PART 7. 데이터 집계하기
#
# > **집계**란 데이터를 요약하는 것입니다.
# > '시군구별로 상가가 몇 개인지', '업종별로 몇 개인지' 등과 같은 것을 구하는 과정입니다.
#
# ### 주요 집계 함수
#
# | 함수 | 설명 | 예시 |
# |------|------|------|
# | `value_counts()` | 각 값의 등장 횟수 세기 | `df['상권업종대분류명'].value_counts()` |
# | `groupby()` | 그룹별로 묶어서 집계 | `df.groupby('시군구명')['경도'].mean()` |
# | `nunique()` | 고유한 값의 수 | `df['상권업종중분류명'].nunique()` |

# %% [markdown]
# 문제 1: 업종대분류명 별로 상가 갯수

# %%
df.columns

# %%
df['상권업종대분류명'].unique()
# Out:
# <StringArray>
# ['음식', '시설관리·임대', '예술·스포츠', '소매', '부동산', '과학·기술', '수리·개인', '보건의료', '숙박', '교육']
# Length: 10, dtype: str

# %%
df['상권업종대분류명'].nunique()
# Out:
# 10

# %%
df['상권업종대분류명'].value_counts()
# Out:
# 상권업종대분류명
# 음식         135884
# 소매         111632
# 과학·기술       93261
# 수리·개인       51626
# 교육          45158
# 부동산         25059
# 시설관리·임대     24231
# 예술·스포츠      20446
# 보건의료        18840
# 숙박           8841
# Name: count, dtype: int64

# %% [markdown]
# 문제 2: 시군구명 별로 상가 갯수

# %%
df['시군구명'].unique()
# Out:
# <StringArray>
# [ '강동구',  '용산구',  '강서구',  '노원구',  '종로구',  '마포구',  '관악구',  '서초구',  '송파구',
#   '광진구',  '강남구',  '은평구',   '중구',  '성북구',  '동작구', '동대문구',  '성동구',  '도봉구',
#  '영등포구',  '구로구',  '중랑구',  '양천구', '서대문구',  '강북구',  '금천구']
# Length: 25, dtype: str

# %%
df['시군구명'].nunique()
# Out:
# 25

# %%
df['시군구명'].value_counts()
# Out:
# 시군구명
# 강남구     64123
# 서초구     38892
# 송파구     33559
# 마포구     30488
# 영등포구    28439
# 강서구     26028
# 중구      24117
# 종로구     20804
# 관악구     19283
# 강동구     19046
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 성동구     17221
# 동대문구    16673
# 은평구     15914
# 용산구     15701
# 양천구     15626
# 성북구     15535
# 노원구     15416
# 중랑구     14571
# 동작구     13724
# 서대문구    13634
# 강북구     12174
# 도봉구     10339
# Name: count, dtype: int64

# %%
df.groupby('시군구명').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='시군구명'>

# %%
df.groupby('시군구명').size().index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='str', name='시군구명')

# %%
df.groupby('시군구명').size().values
# Out:
# array([64123, 19046, 12174, 26028, 19283, 18016, 17921, 17734, 15416,
#        10339, 16673, 13724, 30488, 13634, 38892, 17221, 15535, 33559,
#        15626, 28439, 15701, 15914, 20804, 24117, 14571])

# %%
df.groupby('시군구명').size()
# Out:
# 시군구명
# 강남구     64123
# 강동구     19046
# 강북구     12174
# 강서구     26028
# 관악구     19283
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 노원구     15416
# 도봉구     10339
# 동대문구    16673
# 동작구     13724
# 마포구     30488
# 서대문구    13634
# 서초구     38892
# 성동구     17221
# 성북구     15535
# 송파구     33559
# 양천구     15626
# 영등포구    28439
# 용산구     15701
# 은평구     15914
# 종로구     20804
# 중구      24117
# 중랑구     14571
# dtype: int64

# %%
df.groupby('시군구명').size().reset_index()
# Out:
#     시군구명      0
# 0    강남구  64123
# 1    강동구  19046
# 2    강북구  12174
# 3    강서구  26028
# 4    관악구  19283
# 5    광진구  18016
# 6    구로구  17921
# 7    금천구  17734
# 8    노원구  15416
# 9    도봉구  10339
# 10  동대문구  16673
# 11   동작구  13724
# 12   마포구  30488
# 13  서대문구  13634
# 14   서초구  38892
# 15   성동구  17221
# 16   성북구  15535
# 17   송파구  33559
# 18   양천구  15626
# 19  영등포구  28439
# 20   용산구  15701
# 21   은평구  15914
# 22   종로구  20804
# 23    중구  24117
# 24   중랑구  14571

# %%
df.groupby('시군구명').size().reset_index(name='상가수')
# Out:
#     시군구명    상가수
# 0    강남구  64123
# 1    강동구  19046
# 2    강북구  12174
# 3    강서구  26028
# 4    관악구  19283
# 5    광진구  18016
# 6    구로구  17921
# 7    금천구  17734
# 8    노원구  15416
# 9    도봉구  10339
# 10  동대문구  16673
# 11   동작구  13724
# 12   마포구  30488
# 13  서대문구  13634
# 14   서초구  38892
# 15   성동구  17221
# 16   성북구  15535
# 17   송파구  33559
# 18   양천구  15626
# 19  영등포구  28439
# 20   용산구  15701
# 21   은평구  15914
# 22   종로구  20804
# 23    중구  24117
# 24   중랑구  14571

# %% [markdown]
# 문제 3: 시군구별 업종소분류명에 따른 상가의 갯수는?

# %%
df.groupby('시군구명'     )['상권업종소분류명'].count()
# Out:
# 시군구명
# 강남구     64123
# 강동구     19046
# 강북구     12174
# 강서구     26028
# 관악구     19283
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 노원구     15416
# 도봉구     10339
# 동대문구    16673
# 동작구     13724
# 마포구     30488
# 서대문구    13634
# 서초구     38892
# 성동구     17221
# 성북구     15535
# 송파구     33559
# 양천구     15626
# 영등포구    28439
# 용산구     15701
# 은평구     15914
# 종로구     20804
# 중구      24117
# 중랑구     14571
# Name: 상권업종소분류명, dtype: int64

# %%
df.groupby('시군구명'     )['상호명'].count()
# Out:
# 시군구명
# 강남구     64123
# 강동구     19046
# 강북구     12174
# 강서구     26028
# 관악구     19283
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 노원구     15416
# 도봉구     10339
# 동대문구    16673
# 동작구     13724
# 마포구     30488
# 서대문구    13634
# 서초구     38892
# 성동구     17221
# 성북구     15535
# 송파구     33559
# 양천구     15626
# 영등포구    28439
# 용산구     15701
# 은평구     15914
# 종로구     20804
# 중구      24117
# 중랑구     14571
# Name: 상호명, dtype: int64

# %%
df.groupby('시군구명'     ).size()
# Out:
# 시군구명
# 강남구     64123
# 강동구     19046
# 강북구     12174
# 강서구     26028
# 관악구     19283
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 노원구     15416
# 도봉구     10339
# 동대문구    16673
# 동작구     13724
# 마포구     30488
# 서대문구    13634
# 서초구     38892
# 성동구     17221
# 성북구     15535
# 송파구     33559
# 양천구     15626
# 영등포구    28439
# 용산구     15701
# 은평구     15914
# 종로구     20804
# 중구      24117
# 중랑구     14571
# dtype: int64

# %%
df['시군구명'].value_counts()
# Out:
# 시군구명
# 강남구     64123
# 서초구     38892
# 송파구     33559
# 마포구     30488
# 영등포구    28439
# 강서구     26028
# 중구      24117
# 종로구     20804
# 관악구     19283
# 강동구     19046
# 광진구     18016
# 구로구     17921
# 금천구     17734
# 성동구     17221
# 동대문구    16673
# 은평구     15914
# 용산구     15701
# 양천구     15626
# 성북구     15535
# 노원구     15416
# 중랑구     14571
# 동작구     13724
# 서대문구    13634
# 강북구     12174
# 도봉구     10339
# Name: count, dtype: int64

# %% [markdown]
# #### 두 컬럼의 교차표 만들기
# >  행과 열을 교차해서 개수 세기

# %%
pd.crosstab(df['시군구명'] , df['상권업종대분류명']   )
# Out:
# 상권업종대분류명  과학·기술    교육  보건의료   부동산    소매  수리·개인    숙박  시설관리·임대  예술·스포츠     음식
# 시군구명
# 강남구       18854  6219  3067  3665  9869   4681   511     3132    1779  12346
# 강동구        1681  2008   882  1121  4232   2310   276      724     875   4937
# 강북구         980   764   477   532  2860   1683   183      434     649   3612
# 강서구        3683  2273   958  1280  5117   3203   261     1283    1145   6825
# 관악구        1878  1567   687   908  3845   2491   630      713    1091   5473
# 광진구        2088  1389   592   868  4073   2077   302      784     918   4925
# 구로구        2926  1319   563   704  4104   1849   228      835     822   4571
# 금천구        5814   835   361   737  3312   1432   122      984     545   3592
# 노원구        1022  2022   724   581  3529   1804   103      444     860   4327
# 도봉구         856   904   369   450  2648   1404    59      337     539   2773
# 동대문구       1330  1239   592   820  4585   1860   355      592     694   4606
# 동작구        1198  1395   579   758  3027   1519   383      465     649   3751
# 마포구        5704  2634   752  1161  4837   2690  1192     1616     900   9002
# 서대문구       1515  1341   435   624  2812   1331   363      592     525   4096
# 서초구       12633  3820  1527  2094  6491   2472   308     1819    1082   6646
# 성동구        3829  1193   446   782  3312   1714   224      741     521   4459
# 성북구        1280  1670   546   754  3471   1915   260      485     646   4508
# 송파구        6036  3116  1211  1695  6734   3428   369     1386    1561   8023
# 양천구        1358  2535   685   747  3321   1899    95      481     815   3690
# 영등포구       6196  1813   815  1151  5391   2350   403     1614    1122   7584
# 용산구        2231   880   294   804  3945   1140   449      561     334   5063
# 은평구        1303  1588   679   954  3521   2052   167      547     688   4415
# 종로구        2948  1074   481   558  5547   1102   715     1377     502   6500
# 중구         4698   580   569   636  7604   1129   713     1695     443   6050
# 중랑구        1220   980   549   675  3445   2091   170      590     741   4110

# %%
df['시군구명'].value_counts().head(5)
# Out:
# 시군구명
# 강남구     64123
# 서초구     38892
# 송파구     33559
# 마포구     30488
# 영등포구    28439
# Name: count, dtype: int64

# %%
df['시군구명'].value_counts().head(5).index
# Out:
# Index(['강남구', '서초구', '송파구', '마포구', '영등포구'], dtype='str', name='시군구명')

# %%
top_5 = df['시군구명'].value_counts().head(5).index

# %%
df_top5 = df[ df['시군구명'].isin(top_5)]
df_top5
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류명    상권업종중분류명  \
# 5       MA010120220800218616   골든공인중개사사무소  NaN      부동산     부동산 서비스
# 8       MA010120220809640417        솜노래팡팡  NaN       음식          주점
# 9       MA010120220804301582     한양가구갤러리주  NaN       소매       가구 소매
# 11      MA010120220804484713     세마스포츠마케팅  NaN  시설관리·임대   기타 사업 서비스
# 12      MA010120220800800619  참편한공인중개사사무소  NaN      부동산     부동산 서비스
# ...                      ...          ...  ...      ...         ...
# 534965  MA0106202511A2156972         체도비책  NaN    과학·기술    기타 전문 과학
# 534970  MA0106202511A0871177      우성카드시스템  NaN       소매  안경·정밀기기 소매
# 534971  MA0106202511A0686689          오부찌  NaN       음식          한식
# 534973  MA0106202511A1072506           살림  NaN       소매    기타 상품 소매
# 534976  MA0106202511A2056843         만월다방  한강점       음식       비알코올
#
#                  상권업종소분류명    시도명 시군구명  행정동명                 도로명주소  신우편번호  층정보  \
# 5              부동산 중개/대리업  서울특별시  마포구  성산2동   서울특별시 마포구 월드컵로34길 6   3938  NaN
# 8                   요리 주점  서울특별시  서초구  서초3동  서울특별시 서초구 서초대로50길 75   6650    1
# 9                  가구 소매업  서울특별시  송파구  잠실3동    서울특별시 송파구 올림픽로 215   5503  NaN
# 11      전시/컨벤션/행사 대행 서비스업  서울특별시  강남구  역삼1동  서울특별시 강남구 테헤란로25길 47   6126  NaN
# 12             부동산 중개/대리업  서울특별시  서초구  방배1동   서울특별시 서초구 방배로19길 25   6682    1
# ...                   ...    ...  ...   ...                   ...    ...  ...
# 534965         번역/통역 서비스업  서울특별시  서초구  방배2동  서울특별시 서초구 방배천로18길 38   6677  NaN
# 534970           사무기기 소매업  서울특별시  서초구  서초3동  서울특별시 서초구 서초대로46길 99   6650  NaN
# 534971             백반/한정식  서울특별시  송파구  문정2동    서울특별시 송파구 송파대로 167   5855  NaN
# 534973   그 외 기타 상품 전문 소매업  서울특별시  송파구  잠실2동    서울특별시 송파구 올림픽로 119   5501  NaN
# 534976                 카페  서울특별시  마포구   서강동     서울특별시 마포구 토정로 130   4081  NaN
#
#                 경도         위도
# 5       126.903067  37.564570
# 8       127.013852  37.489862
# 9       127.095047  37.514007
# 11      127.034404  37.503571
# 12      126.993691  37.484844
# ...            ...        ...
# 534965  126.984895  37.482581
# 534970  127.013479  37.490177
# 534971  127.120755  37.484557
# 534973  127.084186  37.512087
# 534976  126.925497  37.545062
#
# [195501 rows x 14 columns]

# %%
교차표 = pd.crosstab(df_top5['시군구명'], df_top5['상권업종대분류명'] )
교차표
# Out:
# 상권업종대분류명  과학·기술    교육  보건의료   부동산    소매  수리·개인    숙박  시설관리·임대  예술·스포츠     음식
# 시군구명
# 강남구       18854  6219  3067  3665  9869   4681   511     3132    1779  12346
# 마포구        5704  2634   752  1161  4837   2690  1192     1616     900   9002
# 서초구       12633  3820  1527  2094  6491   2472   308     1819    1082   6646
# 송파구        6036  3116  1211  1695  6734   3428   369     1386    1561   8023
# 영등포구       6196  1813   815  1151  5391   2350   403     1614    1122   7584

# %%
plt.figure(figsize=(12,4))
sns.heatmap(교차표,
            annot=True,        # 셀 안에 숫자 표시 여부 (True/False)
            fmt='.0f',         # 숫자 형식 (소수점 1자리)
            cmap='YlOrRd',     # 색상맵: 노란→주황→빨강
            linewidths=0.5,    # 셀 구분선 두께
            linecolor='white'  # 셀 구분선 색
           )
plt.title('TOP5 자치구별 대분류명에 따른 상가수')
plt.xticks(rotation=30)
plt.yticks(rotation=0)
plt.show()

# %%
df.pivot_table(
    values='상호명',
    index='시군구명',
    columns='상권업종대분류명',
    aggfunc='count'
)
# Out:
# 상권업종대분류명  과학·기술    교육  보건의료   부동산    소매  수리·개인    숙박  시설관리·임대  예술·스포츠     음식
# 시군구명
# 강남구       18854  6219  3067  3665  9869   4681   511     3132    1779  12346
# 강동구        1681  2008   882  1121  4232   2310   276      724     875   4937
# 강북구         980   764   477   532  2860   1683   183      434     649   3612
# 강서구        3683  2273   958  1280  5117   3203   261     1283    1145   6825
# 관악구        1878  1567   687   908  3845   2491   630      713    1091   5473
# 광진구        2088  1389   592   868  4073   2077   302      784     918   4925
# 구로구        2926  1319   563   704  4104   1849   228      835     822   4571
# 금천구        5814   835   361   737  3312   1432   122      984     545   3592
# 노원구        1022  2022   724   581  3529   1804   103      444     860   4327
# 도봉구         856   904   369   450  2648   1404    59      337     539   2773
# 동대문구       1330  1239   592   820  4585   1860   355      592     694   4606
# 동작구        1198  1395   579   758  3027   1519   383      465     649   3751
# 마포구        5704  2634   752  1161  4837   2690  1192     1616     900   9002
# 서대문구       1515  1341   435   624  2812   1331   363      592     525   4096
# 서초구       12633  3820  1527  2094  6491   2472   308     1819    1082   6646
# 성동구        3829  1193   446   782  3312   1714   224      741     521   4459
# 성북구        1280  1670   546   754  3471   1915   260      485     646   4508
# 송파구        6036  3116  1211  1695  6734   3428   369     1386    1561   8023
# 양천구        1358  2535   685   747  3321   1899    95      481     815   3690
# 영등포구       6196  1813   815  1151  5391   2350   403     1614    1122   7584
# 용산구        2231   880   294   804  3945   1140   449      561     334   5063
# 은평구        1303  1588   679   954  3521   2052   167      547     688   4415
# 종로구        2948  1074   481   558  5547   1102   715     1377     502   6500
# 중구         4698   580   569   636  7604   1129   713     1695     443   6050
# 중랑구        1220   980   549   675  3445   2091   170      590     741   4110

# %%
df_top5.pivot_table(
    values='상호명',
    index='시군구명',
    columns='상권업종대분류명',
    aggfunc='count'
)
# Out:
# 상권업종대분류명  과학·기술    교육  보건의료   부동산    소매  수리·개인    숙박  시설관리·임대  예술·스포츠     음식
# 시군구명
# 강남구       18854  6219  3067  3665  9869   4681   511     3132    1779  12346
# 마포구        5704  2634   752  1161  4837   2690  1192     1616     900   9002
# 서초구       12633  3820  1527  2094  6491   2472   308     1819    1082   6646
# 송파구        6036  3116  1211  1695  6734   3428   369     1386    1561   8023
# 영등포구       6196  1813   815  1151  5391   2350   403     1614    1122   7584

# %% [markdown]
# ---
#
# ## PART 8. 데이터 시각화하기
#
# > **시각화**란 데이터를 그래프나 차트로 표현하는 것입니다.
# > 숫자로만 보면 이해하기 어려운 패턴을 눈으로 바로 확인할 수 있습니다!
#
# ### 그래프 종류 선택 기준
#
# | 그래프 | 언제 사용? | 예시 |
# |--------|-----------|------|
# | 막대 그래프 | 항목 간 크기 비교 | 구별 상가 수 비교 |
# | 파이 차트 | 전체에서 비율 | 업종 비율 |
# | 히스토그램 | 분포 확인 | 상가 수 분포 |
# | 산점도 | 두 변수의 관계 | 위도 vs 경도 |
#
# 1. **pandas `.plot()`** : 가장 간단, Series, DataFrame에 바로 적용
# 2. **seaborn** : 예쁜 통계 그래프
# 3. **matplotlib.pyplot `plt`** : 세밀한 설정 가능

# %% [markdown]
# 문제 1: 상권업종대분류명별 상가 수

# %%
df['상권업종대분류명'].value_counts().index
# Out:
# Index(['음식', '소매', '과학·기술', '수리·개인', '교육', '부동산', '시설관리·임대', '예술·스포츠', '보건의료',
#        '숙박'],
#       dtype='str', name='상권업종대분류명')

# %%
df['상권업종대분류명'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='상권업종대분류명'>

# %%
sns.countplot(data=df, y='상권업종대분류명',
              order=df['상권업종대분류명'].value_counts().sort_values().index )
# Out:
# <Axes: xlabel='count', ylabel='상권업종대분류명'>

# %% [markdown]
# 문제 2: 위도와 경도 산점도

# %%
sns.scatterplot(data=df, x='경도', y='위도')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>

# %% [markdown]
# 과제: 여러분이 서울시 상권에 대하여 알고 싶은 것은 무엇인가요?  (토론방에 제출)
#  > 우선 알고 싶은 것을 한가지만 적어보세요
#  > 먼저 여러분이 어떠한 방법으로 해결할 수 있을지 그 과정을 생각하고 한글로 적어봅니다
#  > AI 에 여러분이 알고 싶은 문제를 주고 코드를 받아 실행해봅니다
#  > 여러분이 그 코드를 보고 어디까지 익숙한 지 **어떠한 것이 새로운 지**에 대한 것을 토론방에 올립니다
#  > 매주 실습하고 있는 노트북 파일들은 **github** 에 잘 보관해두어야 합니다 (포트폴리오: 기말에 github 주소 제출)
#  > 이번 주 과제 : **AI 와 협업한 코드와 여러분이 알게 된 것** 을 적어 **토론방**에 올려주세요
#  > 토론방 활동을 통해 다른 친구들이 공부한 내용을 같이 공유해봅니다
