# %% [markdown]
# # 2주차 데이터 탐색과 시각화 실습
#
# pandas를 사용하여 데이터를 불러오고 데이터의 구조를 이해한 후, 데이터의 분포를 분석하고 matplotlib.pyplot 사용하여 시각화하는 방법을 학습한다.

# %% [markdown]
# ## 2주차 학습 목표
#
# 1. CSV 데이터를 pandas로 불러올 수 있다.
#    - `pd.read_csv()`를 사용하여 CSV 파일을 데이터프레임으로 읽는다.
#
# 2. 데이터프레임의 구조를 탐색할 수 있다.
#    - `info()`를 사용하여 데이터 타입과 결측값 여부를 확인한다.
#    - `columns`를 사용하여 컬럼 이름을 확인한다.
#    - `describe()`를 사용하여 수치 데이터의 기본 통계를 확인한다.
#
# 3. 특정 컬럼 데이터를 선택할 수 있다.
#    - `df['컬럼명']`을 사용하여 특정 컬럼을 선택한다.
#
# 4. 데이터의 고유값을 확인할 수 있다.
#    - `unique()`를 사용하여 해당 컬럼에 어떤 값들이 존재하는지 확인한다.
#
# 5. 데이터의 빈도 분포를 분석할 수 있다.
#    - `value_counts()`를 사용하여 값의 등장 횟수를 계산한다.
#
# 6. 데이터 분석 결과를 시각화할 수 있다.
#    - `value_counts().plot()`를 사용하여 값의 출현 횟수를 그래프로 시각화한다.
#    - `value_counts().plot(kind='bar')`   또는 `value_counts().plot.bar()`를 사용하여 값의 출현 횟수를 막대그래프로 시각화한다.
#    - 를 사용하여 값의 출현 횟수를 막대그래프로 시각화한다
#
# 7. `matplotlib.pyplot` 을 사용하여 그래프를 설정할 수 있다.
#    - `plt.title()`을 사용하여 그래프 제목을 설정한다.
#    - `plt.xlabel()`과 `plt.ylabel()`을 사용하여 축 이름을 설정한다.
#    - `plt.show()`를 사용하여 그래프를 화면에 출력한다.
#
# 8. `groupby()`를 사용하여 데이터를 그룹별로 분석할 수 있다.
#    - `groupby()`를 사용하여 특정 기준으로 데이터를 그룹화한다.
#
# 9. 그룹별 통계값을 계산하여 데이터의 특징을 분석할 수 있다.
#    - `groupby()`와 집계 함수를 사용하여 평균, 최소, 최대, 합계, 갯수 등의 통계를 계산한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic') 
plt.rc('axes',unicode_minus = False)

# %%
df = pd.read_csv('data2.csv')
df

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0       1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 1       1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 4       1    제주    6.7    4.0    9.8    1.4    55.4    4.2
# 5       2    광주    1.1   -2.9    5.7    1.5    64.9    1.5
# 6       2    대전   -0.1   -5.1    5.8    0.7    56.3    2.1
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 9       2    제주    5.2    2.5    8.1    3.6    58.9    4.4
# 10      3    광주    9.3    4.3   15.5    2.6    59.6    1.7
# 11      3    대전    8.6    3.1   14.9    3.1    54.6    2.4
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 14      3    제주   11.5    8.3   15.2    4.6    57.2    4.0
# ...

# %%
df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   60 non-null     int64
#  1   stnNm   60 non-null     object
#  2   avgTa   60 non-null     float64
#  3   minTa   60 non-null     float64
#  4   maxTa   60 non-null     float64
#  5   sumRn   60 non-null     float64
#  6   avgRhm  60 non-null     float64
#  7   avgWs   60 non-null     float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
df.columns

# %%
df.columns
# Out:
# Index(['month', 'stnNm', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgRhm',
#        'avgWs'],
#       dtype='object')

# %%
df.describe()

# %%
df.describe()
# Out:
#            month      avgTa      minTa      maxTa      sumRn     avgRhm  \
# count  60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean    6.500000  15.458333  11.613333  20.038333   9.475000  65.693333
# std     3.481184   9.477436   9.920471   9.145770  11.177272   9.060846
# min     1.000000  -1.200000  -5.300000   3.900000   0.700000  41.000000
# 25%     3.750000   8.450000   3.525000  13.525000   2.925000  58.975000
# 50%     6.500000  15.950000  11.900000  21.450000   5.700000  66.400000
# 75%     9.250000  24.000000  20.125000  28.350000  11.025000  72.175000
# max    12.000000  29.600000  26.900000  33.200000  69.200000  81.200000
#
#            avgWs
# count  60.000000
# mean    2.438333
# std     0.847347
# min     1.100000
# 25%     1.700000
# 50%     2.300000
# 75%     3.125000
# max     4.400000

# %%
df['stnNm']

# %%
df['stnNm']
# Out:
# 0     광주
# 1     대전
# 2     부산
# 3     서울
# 4     제주
# 5     광주
# 6     대전
# 7     부산
# 8     서울
# 9     제주
# 10    광주
# 11    대전
# 12    부산
# 13    서울
# 14    제주
# 15    광주
# 16    대전
# 17    부산
# 18    서울
# 19    제주
# 20    광주
# 21    대전
# 22    부산
# 23    서울
# 24    제주
# 25    광주
# 26    대전
# 27    부산
# 28    서울
# 29    제주
# 30    광주
# 31    대전
# 32    부산
# 33    서울
# 34    제주
# 35    광주
# 36    대전
# 37    부산
# 38    서울
# 39    제주
# 40    광주
# 41    대전
# 42    부산
# 43    서울
# 44    제주
# 45    광주
# 46    대전
# 47    부산
# 48    서울
# 49    제주
# 50    광주
# 51    대전
# 52    부산
# 53    서울
# 54    제주
# 55    광주
# 56    대전
# 57    부산
# 58    서울
# 59    제주
# Name: stnNm, dtype: object

# %% [markdown]
# ### unique() 와 value_counts() 의 차이
#
# 데이터를 분석할 때 특정 컬럼에 어떤 값들이 존재하는지 확인하는 것이 중요
# pandas에서는 이를 위해 `unique()`와 `value_counts()` 함수를 사용할 수 있다.
#
# - `unique()`는 해당 컬럼에 존재하는 **고유한 값의 목록**을 반환
#
# - `value_counts()`는 해당 컬럼에 **각 값이 몇 번 등장하는지**를 반환하고 그 결과는 pandas Series 형태이므로 바로 그래프로 시각화할 수 있다.

# %%
df['stnNm'].unique()

# %%
df['stnNm'].unique()
# Out:
# array(['광주', '대전', '부산', '서울', '제주'], dtype=object)

# %%
df['stnNm'].value_counts()

# %%
df['stnNm'].value_counts()
# Out:
# stnNm
# 광주    12
# 대전    12
# 부산    12
# 서울    12
# 제주    12
# Name: count, dtype: int64

# %%
df['stnNm'].value_counts().plot()

# %%
df['stnNm'].value_counts().plot()
# Out:
# <Axes: xlabel='stnNm'>

# %%
df['stnNm'].value_counts().plot(kind='bar')
plt.show()

# %%
df['stnNm'].value_counts().plot(kind='bar')
plt.show()

# %%
df['stnNm'].value_counts().plot.bar()
plt.show()

# %%
df['stnNm'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ###  문제 1) 특정 지역 데이터만 선택하기 (복습)
#
# - 조건: 'stnNm' 이 '서울' 인 행만 선택
#
# #### 중요
# - 문자열 비교로 조건을 만들고, df[조건] 으로 행 선택!!

# %%
df['stnNm'] == '서울'

# %%
df['stnNm'] == '서울'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# Name: stnNm, dtype: bool

# %%
df_seoul = df[ df['stnNm'] == '서울' ]
df_seoul

# %%
df_seoul = df[ df['stnNm'] == '서울' ]
df_seoul
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 18      4    서울   13.4    8.2   19.0    8.6    60.5    2.5
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 38      8    서울   28.2   25.3   31.9   17.1    75.6    2.3
# 43      9    서울   23.4   20.3   27.4   23.2    75.4    2.0
# 48     10    서울   16.5   13.1   20.4   10.4    75.5    2.3
# 53     11    서울    9.0    4.6   14.2    3.0    61.3    2.1
# 58     12    서울    1.2   -2.9    5.3    3.7    61.3    2.3

# %% [markdown]
# ### 문제 2) 행 선택 후 필요한 열만 보기 (복습)
# - 서울 지역의 평균기온의 최소값
# - 서울 데이터에서 'minTa', 'maxTa', 'sumRn' 열들만 선택하여 평균값

# %%
df_seoul['avgTa'].min()

# %%
df_seoul['avgTa'].min()
# Out:
# -1.2

# %%
df_seoul[[ 'minTa', 'maxTa', 'sumRn' ] ].mean().round(2)

# %%
df_seoul[[ 'minTa', 'maxTa', 'sumRn' ] ].mean().round(2)
# Out:
# minTa    10.12
# maxTa    18.62
# sumRn     8.73
# dtype: float64

# %% [markdown]
# ### 문제 3) 서울의 월별 평균기온을 그래프로 그리기
#
# - df_seoul 을 이용하여 'month'를 x축, 'avgTa'를 y축으로 그래프 그리기
# - `plt.title()`, `plt.xlabel()`, `plt.ylabel()` 등을 사용해 그래프 정보를 명확히 해보세요
#
# #### 힌트
# - df_seoul.plot(x=    , y=     )을 사용
# - plt.plot(     ,     ) 을 사용

# %%
df_seoul.plot(x='month'  ,   y='avgTa')
plt.title('서울의 월별 평균기온')
plt.xlabel('월')
plt.ylabel('평균기온')
plt.show()

# %%
df_seoul.plot(x='month'  ,   y='avgTa')
plt.title('서울의 월별 평균기온')
plt.xlabel('월')
plt.ylabel('평균기온')
plt.show()

# %%
plt.plot( df_seoul['month']       ,  df_seoul['avgTa']      )
plt.title('서울의 월별 평균기온')
plt.xlabel('월')
plt.ylabel('평균기온')
plt.show()

# %%
plt.plot( df_seoul['month']       ,  df_seoul['avgTa']      )
plt.title('서울의 월별 평균기온')
plt.xlabel('월')
plt.ylabel('평균기온')
plt.show()

# %% [markdown]
# ## 그룹핑 : 묶어서 계산하기
#
# - groupby() 함수 : 기준 컬럼으로 데이터를 묶은 뒤  묶음별 통계값을 계산

# %% [markdown]
# ### 문제 4) 지역 ('stnNm') 별 평균기온('avgTa') 의 평균을 계산

# %%
df.groupby('stnNm')['avgTa'].mean()

# %%
df.groupby('stnNm')['avgTa'].mean()
# Out:
# stnNm
# 광주    15.225000
# 대전    14.441667
# 부산    15.975000
# 서울    14.058333
# 제주    17.591667
# Name: avgTa, dtype: float64

# %%
type(df.groupby('stnNm')['avgTa'].mean())
# Out:
# pandas.core.series.Series

# %%
df.groupby('stnNm')['avgTa'].mean().plot(kind='bar')
plt.title('지역별 연간 평균기온')
plt.xlabel('지역')
plt.ylabel('평균기온')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('stnNm')['avgTa'].mean().plot(kind='bar')
plt.title('지역별 연간 평균기온')
plt.xlabel('지역')
plt.ylabel('평균기온')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 문제 5) 달 ('month') 별 강수량 ('sumRn') 의 평균을 계산

# %%
df.groupby('month')['sumRn'].mean()

# %%
df.groupby('month')['sumRn'].mean()
# Out:
# month
# 1      1.16
# 2      2.42
# 3      3.34
# 4      6.04
# 5      8.44
# 6     15.24
# 7     32.70
# 8     15.58
# 9     13.34
# 10     8.80
# 11     4.24
# 12     2.40
# Name: sumRn, dtype: float64

# %%
df.groupby('month')['sumRn'].mean().plot(marker='o')
plt.title('월별 평균 강수량')
plt.xlabel('월')
plt.ylabel('강수량')
plt.xticks(df.groupby('month')['sumRn'].mean().index)
plt.show()

# %%
df.groupby('month')['sumRn'].mean().plot(marker='o')
plt.title('월별 평균 강수량')
plt.xlabel('월')
plt.ylabel('강수량')
plt.xticks(df.groupby('month')['sumRn'].mean().index)
plt.show()

# %% [markdown]
# ### 문제 6) 지역별 평균기온, 강수량 의 평균 구하고 시각화

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean()

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean()
# Out:
#            avgTa      sumRn
# stnNm
# 광주     15.225000  13.491667
# 대전     14.441667   9.350000
# 부산     15.975000  10.241667
# 서울     14.058333   8.725000
# 제주     17.591667   5.566667

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean().plot()

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean().plot()
# Out:
# <Axes: xlabel='stnNm'>

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean().plot.bar()

# %%
df.groupby('stnNm')[['avgTa', 'sumRn'  ]].mean().plot.bar()
# Out:
# <Axes: xlabel='stnNm'>

# %% [markdown]
# ### 문제 7) 월 별 최저기온, 평균기온, 최고기온의 평균 구하고 시각화

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean()

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean()
# Out:
#        minTa  avgTa  maxTa
# month
# 1      -1.20   2.54   7.06
# 2      -2.40   1.58   6.28
# 3       5.00   9.44  14.68
# 4       9.30  14.36  20.00
# 5      13.62  17.88  22.64
# 6      19.72  23.54  27.92
# 7      24.96  28.28  32.26
# 8      25.34  28.42  32.36
# 9      21.82  24.70  28.66
# 10     15.64  18.66  22.64
# 11      6.84  11.16  16.38
# 12      0.72   4.94   9.58

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean().plot()
plt.title('월별 최저기온, 평균기온, 최고기온')
plt.xlabel('월')
plt.ylabel('기온')
plt.show()

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean().plot()
plt.title('월별 최저기온, 평균기온, 최고기온')
plt.xlabel('월')
plt.ylabel('기온')
plt.show()

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean().plot.bar()
plt.title('월별 최저기온, 평균기온, 최고기온')
plt.xlabel('월')
plt.ylabel('기온')
plt.xticks(rotation=0)
plt.show()

# %%
df.groupby('month')[['minTa', 'avgTa', 'maxTa']].mean().plot.bar()
plt.title('월별 최저기온, 평균기온, 최고기온')
plt.xlabel('월')
plt.ylabel('기온')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 복습 문제

# %% [markdown]
# 1. 데이터의 처음 5개 행을 출력

# %%
df.head()
# Out:
#    month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 0      1    광주    1.9   -2.0    6.8    1.2    67.8    1.2
# 1      1    대전    0.5   -4.1    6.0    0.7    62.8    1.6
# 2      1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3      1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 4      1    제주    6.7    4.0    9.8    1.4    55.4    4.2

# %% [markdown]
# 2. `stnNm` 열에는 어떤 지역들이 있는지 확인

# %%
df['stnNm'].unique()
# Out:
# array(['광주', '대전', '부산', '서울', '제주'], dtype=object)

# %% [markdown]
# 3. `stnNm` 컬럼에는 총 몇 개의 지역이 있는가? (처음 배웁니다!!)

# %%
df['stnNm'].nunique()

# %%
df['stnNm'].nunique()
# Out:
# 5

# %% [markdown]
# 4. 각 지역(`stnNm`)의 데이터 개수를 계산해보면

# %%
df['stnNm'].value_counts()
# Out:
# stnNm
# 광주    12
# 대전    12
# 부산    12
# 서울    12
# 제주    12
# Name: count, dtype: int64

# %% [markdown]
# 5. `stnNm`이 **부산**인 데이터만 선택해 보면

# %%
df[df['stnNm'] == '부산']
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 17      4    부산   14.0   10.4   18.3    7.5    62.2    3.8
# 22      5    부산   17.4   14.1   21.4   10.2    71.4    3.2
# 27      6    부산   22.3   19.7   25.7   24.4    77.4    3.3
# 32      7    부산   27.8   24.9   31.3   34.5    73.3    3.1
# 37      8    부산   28.4   25.8   31.9   17.6    77.7    3.3
# 42      9    부산   25.6   23.1   29.6    3.6    74.3    3.0
# 47     10    부산   19.6   17.0   23.6    8.4    71.3    2.5
# 52     11    부산   12.9    8.7   17.9    5.1    52.8    2.9
# 57     12    부산    7.0    2.8   11.9    1.5    48.5    2.5

# %% [markdown]
# 6. 최고 기온이 **30도 이상**인 데이터를 선택

# %%
df[df['maxTa'] >= 30]
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 30      7    광주   28.2   24.1   33.2   69.2    73.4    1.6
# 31      7    대전   28.3   24.3   32.9   27.3    71.0    1.9
# 32      7    부산   27.8   24.9   31.3   34.5    73.3    3.1
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 34      7    제주   28.3   25.8   31.3   12.9    71.6    3.2
# 35      8    광주   27.7   24.3   32.2   30.9    79.6    1.2
# 36      8    대전   28.2   24.4   32.9    8.1    75.6    1.6
# 37      8    부산   28.4   25.8   31.9   17.6    77.7    3.3
# 38      8    서울   28.2   25.3   31.9   17.1    75.6    2.3
# 39      8    제주   29.6   26.9   32.9    4.2    70.6    2.8
# 44      9    제주   27.1   24.6   30.3   13.1    73.4    2.8

# %% [markdown]
# 7. `stnNm`이 **서울 또는 부산**인 데이터를 선택

# %%
df[(df['stnNm'] == '서울') | (df['stnNm'] == '부산')]
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 2       1    부산    4.0    0.2    8.8    1.1    45.0    3.4
# 3       1    서울   -0.4   -4.1    3.9    1.4    61.1    2.3
# 7       2    부산    2.9   -1.2    7.9    5.3    41.0    3.6
# 8       2    서울   -1.2   -5.3    3.9    1.0    55.7    2.6
# 12      3    부산    9.8    6.0   14.2    3.7    58.0    3.7
# 13      3    서울    8.0    3.3   13.6    2.7    56.1    2.8
# 17      4    부산   14.0   10.4   18.3    7.5    62.2    3.8
# 18      4    서울   13.4    8.2   19.0    8.6    60.5    2.5
# 22      5    부산   17.4   14.1   21.4   10.2    71.4    3.2
# 23      5    서울   17.8   13.3   22.7    8.2    66.9    2.3
# 27      6    부산   22.3   19.7   25.7   24.4    77.4    3.3
# 28      6    서울   24.0   20.0   28.5    5.8    68.3    2.3
# 32      7    부산   27.8   24.9   31.3   34.5    73.3    3.1
# 33      7    서울   28.8   25.7   32.6   19.6    71.8    2.3
# 37      8    부산   28.4   25.8   31.9   17.6    77.7    3.3
# ...

# %% [markdown]
# 8. `stnNm`이 **광주**이고 평균 기온이 **20도 이상**인 데이터를 선택

# %%
df[(df['stnNm'] == '광주') & (df['avgTa'] >= 20)]
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 25      6    광주   24.0   19.5   29.0   17.6    70.8    1.6
# 30      7    광주   28.2   24.1   33.2   69.2    73.4    1.6
# 35      8    광주   27.7   24.3   32.2   30.9    79.6    1.2
# 40      9    광주   24.1   21.0   28.3   10.4    80.7    1.3

# %% [markdown]
# 9. 지역별 강수량 합계를 구하고 시각화

# %%
df.groupby('stnNm')['sumRn'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='stnNm'>

# %% [markdown]
# 10. 우리나라에서 **가장 더운 지역은 어디일까?**

# %%
df.sort_values('maxTa', ascending=False).head(1)

# %%
df.sort_values('maxTa', ascending=False).head(1)
# Out:
#     month stnNm  avgTa  minTa  maxTa  sumRn  avgRhm  avgWs
# 30      7    광주   28.2   24.1   33.2   69.2    73.4    1.6

# %% [markdown]
# 여러분 어떻게 공부했나요??
#
# 이번 주 공부하면서 어려움은 없었나요?  어떠한 것을 알게 되었나요?
#
# 나에게 전하고 싶은 말 등을 아래 셀에 적어주세요
#
# 제출은 `**3번째인 이번 노트북만**` 제출해주세요!!

# %%
영상에 나온 대로 따라 해보니 어렵지 않게 따라갈 수 있었던 것 같습니다.
아직까진 큰 어려움은 없는 것 같습니다.
